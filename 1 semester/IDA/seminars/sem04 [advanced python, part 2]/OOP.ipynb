# %% [markdown]
# # Классы

# %%
from datetime import datetime, timedelta

# %%
class TimeInterval:
    """
    Class describes time interval
    """
    
    def __init__(self, begin, end):
        self.begin = begin
        self.end = end
        
    def get_length(self):
        return self.end - self.begin

# %%
interval = TimeInterval(
    datetime(year=2018, month=8, day=6),
    datetime.now()
)

# %%
interval

# %%
print(type(interval))
# Out:
# <class '__main__.TimeInterval'>

# %%
print(type(TimeInterval))
# Out:
# <class 'type'>

# %% [markdown]
# ## Атрибуты

# %%
dir(interval)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'begin',
#  'end',
#  'get_length']

# %%
interval.__dict__
# Out:
# {'begin': datetime.datetime(2018, 8, 6, 0, 0),
#  'end': datetime.datetime(2018, 10, 7, 19, 51, 36, 586123)}

# %%
TimeInterval.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__doc__': '\n    Class describes time interval\n    ',
#               '__init__': <function __main__.TimeInterval.__init__(self, begin, end)>,
#               'get_length': <function __main__.TimeInterval.get_length(self)>,
#               '__dict__': <attribute '__dict__' of 'TimeInterval' objects>,
#               '__weakref__': <attribute '__weakref__' of 'TimeInterval' objects>})

# %%
interval.begin
# Out:
# datetime.datetime(2018, 8, 6, 0, 0)

# %%
getattr(interval, 'begin')
# Out:
# datetime.datetime(2018, 8, 6, 0, 0)

# %%
interval.not_found_attr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7dd0e861ede7> in <module>()
# ----> 1 interval.not_found_attr
#
# AttributeError: 'TimeInterval' object has no attribute 'not_found_attr'

# %%
interval.attr_to_set = 1256
print(interval.attr_to_set)
interval.__dict__
# Out:
# 1256
# {'begin': datetime.datetime(2018, 8, 6, 0, 0),
#  'end': datetime.datetime(2018, 10, 7, 19, 51, 36, 586123),
#  'attr_to_set': 1256}

# %%
del interval.attr_to_set
print(interval.__dict__)
interval.attr_to_set
# Out:
# {'begin': datetime.datetime(2018, 8, 6, 0, 0), 'end': datetime.datetime(2018, 10, 7, 19, 51, 36, 586123)}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-48b857b24042> in <module>()
#       1 del interval.attr_to_set
#       2 print(interval.__dict__)
# ----> 3 interval.attr_to_set
#
# AttributeError: 'TimeInterval' object has no attribute 'attr_to_set'

# %% [markdown]
# ## Методы

# %%
interval.get_length()
# Out:
# datetime.timedelta(62, 71496, 586123)

# %%
interval.get_length
# Out:
# <bound method TimeInterval.get_length of <__main__.TimeInterval object at 0x7f78005ccb70>>

# %%
TimeInterval.get_length
# Out:
# <function __main__.TimeInterval.get_length(self)>

# %%
TimeInterval.get_length(interval)
# Out:
# datetime.timedelta(62, 71496, 586123)

# %%
interval.not_found_method()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2d5467e4b053> in <module>()
# ----> 1 interval.not_found_method()
#
# AttributeError: 'TimeInterval' object has no attribute 'not_found_method'

# %% [markdown]
# ## Инкапсуляция ?

# %%
class TimeInterval:    
    def __init__(self, begin, end):
        self.__begin = begin
        self._end = end
        
    def get_length(self):
        return self._end - self.__begin

# %%
interval = TimeInterval(
    datetime(year=2018, month=8, day=6, hour=10, minute=7),
    datetime(year=2018, month=8, day=6, hour=12, minute=30),
)

# %%
interval._end
# Out:
# datetime.datetime(2018, 8, 6, 12, 30)

# %%
interval.__begin
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-db79a5e55077> in <module>()
# ----> 1 interval.__begin
#
# AttributeError: 'TimeInterval' object has no attribute '__begin'

# %%
interval.__dict__
# Out:
# {'_TimeInterval__begin': datetime.datetime(2018, 8, 6, 10, 7),
#  '_end': datetime.datetime(2018, 8, 6, 12, 30)}

# %%
interval._TimeInterval__begin
# Out:
# datetime.datetime(2018, 8, 6, 10, 7)

# %%
interval.get_length().total_seconds()
# Out:
# 8580.0

# %% [markdown]
# ## Атрибуты классов

# %%
from time import sleep

# %%
class TimeInterval:
    # а-ля static DEFAULT_BEGIN
    DEFAULT_BEGIN = datetime(1970, 1, 1)
    DEFAULT_END   = datetime.now()
    
    def __init__(self, begin=None, end=None):
        if begin is None:
            begin = self.DEFAULT_BEGIN
        if end is None:
            end = self.DEFAULT_END
        
        self._begin = begin
        self._end = end
        
    def get_length(self):
        return self._end - self._begin
    
    def set_default_end(self, value):
        self.DEFAULT_END = value

# %%
TimeInterval.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'DEFAULT_BEGIN': datetime.datetime(1970, 1, 1, 0, 0),
#               'DEFAULT_END': datetime.datetime(2018, 10, 7, 19, 51, 53, 592856),
#               '__init__': <function __main__.TimeInterval.__init__(self, begin=None, end=None)>,
#               'get_length': <function __main__.TimeInterval.get_length(self)>,
#               'set_default_end': <function __main__.TimeInterval.set_default_end(self, value)>,
#               '__dict__': <attribute '__dict__' of 'TimeInterval' objects>,
#               '__weakref__': <attribute '__weakref__' of 'TimeInterval' objects>,
#               '__doc__': None})

# %%
interval = TimeInterval()
print("Before: ", interval.DEFAULT_END)

sleep(3)

print("Current:", datetime.now())

interval = TimeInterval()
print("After:  ", interval.DEFAULT_END)
# Out:
# Before:  2018-10-07 19:51:53.592856
# Current: 2018-10-07 19:51:57.675537
# After:   2018-10-07 19:51:53.592856

# %%
interval.set_default_end(datetime.now())
print(TimeInterval.DEFAULT_END)
print(interval.DEFAULT_END)
# Out:
# 2018-10-07 19:51:53.592856
# 2018-10-07 19:51:57.687617

# %%
interval.__dict__
# Out:
# {'_begin': datetime.datetime(1970, 1, 1, 0, 0),
#  '_end': datetime.datetime(2018, 10, 7, 19, 51, 53, 592856),
#  'DEFAULT_END': datetime.datetime(2018, 10, 7, 19, 51, 57, 687617)}

# %%
interval = TimeInterval()
interval.__dict__
# Out:
# {'_begin': datetime.datetime(1970, 1, 1, 0, 0),
#  '_end': datetime.datetime(2018, 10, 7, 19, 51, 53, 592856)}

# %%
class TimeInterval:
    # а-ля static DEFAULT_BEGIN
    DEFAULT_BEGIN = datetime(1970, 1, 1)
    DEFAULT_END   = datetime.now()
    
    def __init__(self, begin=None, end=None):
        if begin is None:
            begin = self.DEFAULT_BEGIN
        if end is None:
            end = self.DEFAULT_END
        
        self._begin = begin
        self._end = end
        
    def get_length(self):
        return self._end - self._begin
    
    """
    def set_default_end(self, value):
        TimeInterval.DEFAULT_END = value
    """

    # """
    @classmethod
    def set_default_end(cls, value):
        cls.DEFAULT_END = value
    # """
        
interval = TimeInterval()

# %%
TimeInterval.get_length
# Out:
# <function __main__.TimeInterval.get_length(self)>

# %%
interval.get_length
# Out:
# <bound method TimeInterval.get_length of <__main__.TimeInterval object at 0x7f780056dcf8>>

# %%
TimeInterval.set_default_end
# Out:
# <bound method TimeInterval.set_default_end of <class '__main__.TimeInterval'>>

# %%
TimeInterval.set_default_end(datetime.now())
print(TimeInterval.DEFAULT_END)
print(interval.DEFAULT_END)
# Out:
# 2018-10-07 19:51:58.381393
# 2018-10-07 19:51:58.381393

# %%
interval.set_default_end(datetime.now())
print(TimeInterval.DEFAULT_END)
print(interval.DEFAULT_END)
# Out:
# 2018-10-07 19:51:58.877453
# 2018-10-07 19:51:58.877453

# %%
class TimeInterval:
    # а-ля static DEFAULT_BEGIN
    DEFAULT_BEGIN = datetime(1970, 1, 1)
    
    def __init__(self, begin=None, end=None):
        if begin is None:
            begin = self.DEFAULT_BEGIN
        if end is None:
            end = self.get_default_end()
        
        self._begin = begin
        self._end = end
        
    def get_length(self):
        return self._end - self._begin
    
    @staticmethod
    def get_default_begin():
        # обязательно явно указывать имя класса
        return TimeInterval.DEFAULT_BEGIN
    
    # лучше
    """
    @classmethod
    def get_default_begin(cls):
        return cls.DEFAULT_BEGIN
    """
    
    @staticmethod
    def get_default_end():
        return datetime.now()

# %%
interval = TimeInterval()
print("Before: ", interval._end)

sleep(3)

print("Current:", datetime.now())

interval = TimeInterval()
print("After:  ", interval._end)
# Out:
# Before:  2018-10-07 19:51:59.862389
# Current: 2018-10-07 19:52:02.865235
# After:   2018-10-07 19:52:02.865425

# %%
print(interval.get_default_end())
print(TimeInterval.get_default_end())
# Out:
# 2018-10-07 19:52:02.873778
# 2018-10-07 19:52:02.873991

# %%
TimeInterval.get_default_end
# Out:
# <function __main__.TimeInterval.get_default_end()>

# %%
interval.get_default_end
# Out:
# <function __main__.TimeInterval.get_default_end()>

# %%
TimeInterval.get_default_begin()
# Out:
# datetime.datetime(1970, 1, 1, 0, 0)

# %% [markdown]
# ## Вычисляемые свойства класса (property)

# %%
class TimeInterval:
    DEFAULT_BEGIN = datetime(1991, 1, 1)
    
    def __init__(self, begin=None, end=None):
        if begin is None:
            begin = self.DEFAULT_BEGIN
        if end is None:
            end = self.get_default_end()
        
        # отсутствует подчеркивание [!]
        self.begin = begin
        self.end = end
        
    def get_length(self):
        return self.end - self.begin
    
    @staticmethod
    def get_default_end():
        return datetime.now()

# %%
# хотим, чтобы начальная дата была позже 1991-01-01

interval = TimeInterval()
interval.begin = datetime(1969, 1, 1)
interval.begin
# Out:
# datetime.datetime(1969, 1, 1, 0, 0)

# %%
class TimeInterval:
    DEFAULT_BEGIN = datetime(1991, 1, 1)
    
    def __init__(self, begin=None, end=None):
        if begin is None or begin < self.DEFAULT_BEGIN:
            begin = self.DEFAULT_BEGIN
        if end is None:
            end = self.get_default_end()
        
        # есть подчеркивание [!]
        self._begin = begin
        self.end = end
    
    begin = property()
    
    @begin.setter
    def begin(self, value):
        if value is None or value < self.DEFAULT_BEGIN:
            value = self.DEFAULT_BEGIN
        self._begin = value

    @begin.getter
    def begin(self):
        return self._begin

    @begin.deleter
    def begin(self):
        del self._begin
        
    def get_length(self):
        return self.end - self._begin
    
    @staticmethod
    def get_default_end():
        return datetime.now()

# %%
interval = TimeInterval()
interval.begin = datetime(1969, 1, 1)
interval.begin
# Out:
# datetime.datetime(1991, 1, 1, 0, 0)

# %%
del interval.begin
interval.begin
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f3876cf4a06f> in <module>()
#       1 del interval.begin
# ----> 2 interval.begin
#
# <ipython-input-48-05a7f0e79088> in begin(self)
#      22     @begin.getter
#      23     def begin(self):
# ---> 24         return self._begin
#      25
#      26     @begin.deleter
#
# AttributeError: 'TimeInterval' object has no attribute '_begin'

# %% [markdown]
# ## Магические методы

# %%
list(filter(lambda attr: attr.startswith("__") and attr.endswith("__"), dir(list)))
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# ### Пример: элемент кольца вычетов по модулю 4

# %%
class RingInt:
    modulo = 4
    
    def __init__(self, value):
        self.value = value % self.modulo
        
    def __add__(self, obj):
        return RingInt(self.value + obj.value)
    
    def __mul__(self, obj):
        return RingInt(self.value * obj.value)

# %%
res = RingInt(2) + RingInt(3)
res.value
# Out:
# 1

# %%
res = RingInt(3) + RingInt(3)
res.value
# Out:
# 2

# %%
res = RingInt(2) * RingInt(3)
res.value
# Out:
# 2

# %%
res = RingInt(3) * RingInt(3)
res.value
# Out:
# 1

# %% [markdown]
# ### Пример: планеты

# %%
class Planet:
    def __init__(self, name, mass, radius):
        self.name = name
        self.mass = mass
        self.radius = radius
        
    def __str__(self):
        return f"[PLANET]\n\tname:   {self.name}\n\tmass:   {self.mass}\n\tradius: {self.radius}"
    
    def __repr__(self):
        return f'Planet("{self.name}", {self.mass}, {self.radius})'
    
earth = Planet("Earth", mass=5.9726, radius=6371)

print(earth)
print(str(earth))
earth
# Out:
# [PLANET]
# 	name:   Earth
# 	mass:   5.9726
# 	radius: 6371
# [PLANET]
# 	name:   Earth
# 	mass:   5.9726
# 	radius: 6371
# Planet("Earth", 5.9726, 6371)

# %%
earth_ = eval(repr(earth))
earth_
# Out:
# Planet("Earth", 5.9726, 6371)

# %% [markdown]
# ### Пример: singleton

# %%
class Singleton:
    instance = None
    
    def __new__(cls):
        if cls.instance is None:
            cls.instance = super().__new__(cls)
        return cls.instance

# %%
a, b = Singleton(), Singleton()

print(a)
print(b)

a is b
# Out:
# <__main__.Singleton object at 0x7f780056d588>
# <__main__.Singleton object at 0x7f780056d588>
# True

# %% [markdown]
# ### Пример: декоратор

# %%
# !rm -r tmp
# !mkdir -p tmp

# %%
def logger(filename):
    def decorator(func):
        def wrapper(*args, **argv):
            result = func(*args, **argv)
            with open(filename, 'a') as f_output:
                f_output.write("func = \"{}\"; result = {}\n".format(func.__name__, result))
            return result
        return wrapper
    return decorator

@logger("tmp/decorator.logs")
def summator(a):
    return sum(a)

summator([1, 2, 3, 5])
# Out:
# 11

# %%
# !cat tmp/decorator.logs
# Out:
# func = "summator"; result = 11

# %%
list(map(lambda cls: "__call__" in dir(cls), [logger, list, set, dict, int, Singleton]))
# Out:
# [True, False, False, False, False, False]

# %%
class Logger:
    def __init__(self, filename):
        self._filename = filename
        
    def __call__(self, func):
        def wrapper(*args, **argv):
            result = func(*args, **argv)
            with open(self._filename, 'a') as f_output:
                f_output.write("func = \"{}\"; result = {}\n".format(func.__name__, result))
            return result
        return wrapper
    
logger = Logger("tmp/decorator.logs")

@logger
def summator(a):
    return sum(a)

summator([1, 2, 3, 5, 6])
# Out:
# 17

# %%
# !cat tmp/decorator.logs
# Out:
# func = "summator"; result = 11
# func = "summator"; result = 17

# %% [markdown]
# ### Пример: итератор

# %%
def my_range(start, end, step=1):
    curr = start
    while curr < end:
        yield curr
        curr += step
        
for i in my_range(1, 7, 2):
    print(i)
# Out:
# 1
# 3
# 5

# %%
list(map(lambda a: a in dir(my_range(1, 7, 2)), ['__iter__', '__next__']))
# Out:
# [True, True]

# %%
class Range():
    def __init__(self, start, end, step=1):
        self._current = start
        self._end = end
        self._step = step
        
    def __iter__(self):
        return self
    
    def __next__(self):
        if self._current >= self._end:
            raise StopIteration()
        
        ret = self._current
        self._current += self._step
        return ret

# %%
for i in Range(1, 7, 2):
    print(i)
# Out:
# 1
# 3
# 5

# %%
r = Range(1, 7, 2)

print(next(r))
print(next(r))
print(next(r))
print(next(r))
# Out:
# 1
# 3
# 5
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-71-caf91738afca> in <module>()
#       4 print(next(r))
#       5 print(next(r))
# ----> 6 print(next(r))
#
# <ipython-input-69-55b5c2e8ce3f> in __next__(self)
#      10     def __next__(self):
#      11         if self._current >= self._end:
# ---> 12             raise StopIteration()
#      13
#      14         ret = self._current
#
# StopIteration:

# %% [markdown]
# ## Наследование

# %%
class Rectangle:
    def __init__(self, width, height, secret=",S2v3oABJfos"):
        self._width  = width
        self._height = height
        
        self.__secret = secret
        
    def area(self):
        return self._width * self._height
    
    def trick_secret(self):
        return self.__secret[5:] + self.__secret[:5]

    
class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)
        
    def show_secret(self):
        print(self.__secret)

# %%
print("Rectangle:", Rectangle(2, 3).area())
print("Square:", Square(5).area())
# Out:
# Rectangle: 6
# Square: 25

# %%
square = Square(5)
square._width
# Out:
# 5

# %%
square.show_secret()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-01ddf4b02ee7> in <module>()
# ----> 1 square.show_secret()
#
# <ipython-input-72-897590aed5f2> in show_secret(self)
#      18
#      19     def show_secret(self):
# ---> 20         print(self.__secret)
#
# AttributeError: 'Square' object has no attribute '_Square__secret'

# %%
square.__dict__
# Out:
# {'_width': 5, '_height': 5, '_Rectangle__secret': ',S2v3oABJfos'}

# %%
square.trick_secret()
# Out:
# 'oABJfos,S2v3'

# %% [markdown]
# ### Перегрузка операторов ?

# %%
class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)
        
    def trick_secret(self, message):
        return "I don't know secret message. Let's try this one: " + message
    
square = Square(5)

# %%
square.trick_secret()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-595253b164c4> in <module>()
# ----> 1 square.trick_secret()
#
# TypeError: trick_secret() missing 1 required positional argument: 'message'

# %%
class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)
        
Square.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__init__': <function __main__.Square.__init__(self, side)>,
#               '__doc__': None})

# %%
class Porter:
    def greetings(self):
        print("Hello world!")
    
    def greetings(self, a):
        print(f"Bonjour, {a}!")

# %%
p = Porter()
p.greetings('Alexandr')
p.greetings()
# Out:
# Bonjour, Alexandr!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-f97e8405eca4> in <module>()
#       1 p = Porter()
#       2 p.greetings('Alexandr')
# ----> 3 p.greetings()
#
# TypeError: greetings() missing 1 required positional argument: 'a'

# %% [markdown]
# ## Абстрактные классы

# %%
from math import pi

from abc import ABCMeta, abstractmethod


class Figure(metaclass=ABCMeta):
    @abstractmethod
    def area(self):
        pass


class Circle(Figure):
    def __init__(self, radius):
        self._radius = radius
        
    def area(self):
        return pi * self._radius ** 2


class Rectangle(Figure):
    def __init__(self, width, height):
        self._width  = width
        self._height = height
        
    def area(self):
        return self._width * self._height

    
class Square(Rectangle):
    def __init__(self, side):
        super().__init__(side, side)

# %%
print("Rectangle:", Rectangle(2, 3).area())
print("Square:", Square(5).area())
print("Circle:", Circle(1.5).area())
print("Figure:", Figure().area())
# Out:
# Rectangle: 6
# Square: 25
# Circle: 7.0685834705770345
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-5f80bfa034fb> in <module>()
#       2 print("Square:", Square(5).area())
#       3 print("Circle:", Circle(1.5).area())
# ----> 4 print("Figure:", Figure().area())
#
# TypeError: Can't instantiate abstract class Figure with abstract methods area

# %% [markdown]
# ## Множественное наследование

# %%
class A:
    def __init__(self, a):
        print("A's __init__ is called")
        self.a = a
    
    def method(self):
        print("A's method is called")
        
class B:
    def __init__(self, b):
        print("B's __init__ is called")
        self.b = b
    
    def method(self):
        print("B's method is called")

# %%
class C(A, B):
    def __init__(self, a, b):
        print("C's __init__ is called")
        A.__init__(self, a)
        B.__init__(self, b)
    
    def method(self):
        print("C's method is called")

# %%
C.__bases__
# Out:
# (__main__.A, __main__.B)

# %%
c = C(12, 5)
print("c.a =", c.a)
print("c.b =", c.b)
c.method()
# Out:
# C's __init__ is called
# A's __init__ is called
# B's __init__ is called
# c.a = 12
# c.b = 5
# C's method is called

# %%
c.__dict__
# Out:
# {'a': 12, 'b': 5}

# %%
class C(A, B):
    def __init__(self, a, b):
        print("C's __init__ is called")
        A.__init__(self, a)
        B.__init__(self, b)

# %%
c = C(12, 5)
c.method()
# Out:
# C's __init__ is called
# A's __init__ is called
# B's __init__ is called
# A's method is called

# %%
class C(A, B):
    def __init__(self, a, b):
        print("C's __init__ is called")
        A.__init__(self, a)
        B.__init__(self, b)
        
    def method(self):
        return super().method()

# %%
c = C(12, 5)
c.method()
# Out:
# C's __init__ is called
# A's __init__ is called
# B's __init__ is called
# A's method is called

# %%
# method resolution order
C.__mro__
# Out:
# (__main__.C, __main__.A, __main__.B, object)

# %%
class A:
    def __init__(self, a):
        print("A's __init__ is called")
        self.a = a
        
class B:
    def __init__(self, b):
        print("B's __init__ is called")
        self.b = b
    
    def method(self):
        print("B's method is called")
        
class C(A, B):
    def __init__(self, a, b):
        print("C's __init__ is called")
        A.__init__(self, a)
        B.__init__(self, b)

# %%
c = C(12, 5)
c.method()
# Out:
# C's __init__ is called
# A's __init__ is called
# B's __init__ is called
# B's method is called

# %%
print("{:20}  type  isinstance".format(''))
for cls in C.__mro__:
    print("{:20}  {:4}  {:10}".format(str(cls), type(c) is cls, isinstance(c, cls)))
# Out:
#                       type  isinstance
# <class '__main__.C'>     1           1
# <class '__main__.A'>     0           1
# <class '__main__.B'>     0           1
# <class 'object'>         0           1

# %% [markdown]
# ## Как работает super?

# %%
class A:    
    def get_some(self):
        super().get_some()

class B:
    def get_some(self):
        print('Some')
        
class C(A, B):
    def get_some(self):
        super().get_some()

c = C()
c.get_some()
# Out:
# Some

# %%
C.__mro__
# Out:
# (__main__.C, __main__.A, __main__.B, object)

# %%
class A:
    def get_some(self):
        print('#A', super())
        super().get_some()

class B:
    def get_some(self):
        print('#B', super())
        print('Some')

class C(A, B):
    def get_some(self):
        print('#C', super())
        super().get_some()

c = C()
c.get_some()
# Out:
# #C <super: <class 'C'>, <C object>>
# #A <super: <class 'A'>, <C object>>
# #B <super: <class 'B'>, <C object>>
# Some

# %%
class A:
    def get_some(self):
        super(A, self).get_some()

class B:
    def get_some(self):
        print('Some')

class C(A, B):
    def get_some(self):
        super(C, self).get_some()

c = C()
c.get_some()
# Out:
# Some

# %%
C.__mro__
# Out:
# (__main__.C, __main__.A, __main__.B, object)

# %%
a = A()
a.get_some()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-16a0706968e9> in <module>()
#       1 a = A()
# ----> 2 a.get_some()
#
# <ipython-input-101-c7ecbced4798> in get_some(self)
#       1 class A:
#       2     def get_some(self):
# ----> 3         super(A, self).get_some()
#       4
#       5 class B:
#
# AttributeError: 'super' object has no attribute 'get_some'

# %%
A.__mro__
# Out:
# (__main__.A, object)

# %% [markdown]
# Подробнее о Method Resolution Order (MRO) можно прочитать [здесь](https://habr.com/post/62203/).
