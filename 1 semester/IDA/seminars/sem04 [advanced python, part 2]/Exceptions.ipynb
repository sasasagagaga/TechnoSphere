# %% [markdown]
# # Исключения

# %%
import sys
import os

# %%
def mean(a):
    return sum(a) / len(a)

# %%
mean([1, 2, 3])
# Out:
# 2.0

# %%
mean([])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-21c57292daaa> in <module>()
# ----> 1 mean([])
#
# <ipython-input-2-6f1d8009ce7a> in mean(a)
#       1 def mean(a):
# ----> 2     return sum(a) / len(a)
#
# ZeroDivisionError: division by zero

# %%
raise ZeroDivisionError("message")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-5c5256792634> in <module>()
# ----> 1 raise ZeroDivisionError("message")
#
# ZeroDivisionError: message

# %%
try:
    mean([])
except ZeroDivisionError:
    print("Error occured")
# Out:
# Error occured

# %%
try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\"".format(e))
# Out:
# Error occured "division by zero"

# %%
issubclass(ZeroDivisionError, Exception)
# Out:
# True

# %%
try:
    mean([])
except Exception as e:
    print("Error occured \"{}\"".format(e))
# Out:
# Error occured "division by zero"

# %%
try:
    mean([])
except:
    print("Error occured")
# Out:
# Error occured

# %%
try:
    mean([])
except KeyError as e:
    print("#KE Error occured \"{}\". Type: {}".format(e, type(e)))
except ZeroDivisionError as e:
    print("#ZD Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# #ZD Error occured "division by zero". Type: <class 'ZeroDivisionError'>

# %%
# круглые скобки обязательны

try:
    mean([])
except (KeyError, TypeError, ZeroDivisionError) as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
    
try:
    {'key': 0.0}['value']
except (KeyError, TypeError, ZeroDivisionError) as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# Error occured "'value'". Type: <class 'KeyError'>

# %%
try:
    2 / 3
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
finally:
    print("Don't worry! Be happy!")

print()

try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
finally:
    print("That which does not kill us makes us stronger!")
# Out:
# Don't worry! Be happy!
#
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# That which does not kill us makes us stronger!

# %%
try:
    2 / 3
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
else:
    print("Don't worry! Be happy!")
finally:
    print("That which does not kill us makes us stronger!")
    
print()
    
try:
    mean([])
except ZeroDivisionError as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
else:
    print("Don't worry! Be happy!")
finally:
    print("That which does not kill us makes us stronger!")
# Out:
# Don't worry! Be happy!
# That which does not kill us makes us stronger!
#
# Error occured "division by zero". Type: <class 'ZeroDivisionError'>
# That which does not kill us makes us stronger!

# %%
class AmigoException(ZeroDivisionError):
    """
    Custom exception
    """
    pass

# %%
try:
    mean([])
except AmigoException as e:
    print("Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-0487c81f8fb5> in <module>()
#       1 try:
# ----> 2     mean([])
#       3 except AmigoException as e:
#       4     print("Error occured \"{}\". Type: {}".format(e, type(e)))
#
# <ipython-input-2-6f1d8009ce7a> in mean(a)
#       1 def mean(a):
# ----> 2     return sum(a) / len(a)
#
# ZeroDivisionError: division by zero

# %%
try:
    raise AmigoException("Over all!")
except AmigoException as e:
    print("#AM Error occured \"{}\". Type: {}".format(e, type(e)))
except ZeroDivisionError as e:
    print("#ZD Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# #AM Error occured "Over all!". Type: <class '__main__.AmigoException'>

# %%
try:
    raise AmigoException("Over all!")
except ZeroDivisionError as e:
    print("#ZD Error occured \"{}\". Type: {}".format(e, type(e)))
except AmigoException as e:
    print("#AM Error occured \"{}\". Type: {}".format(e, type(e)))
# Out:
# #ZD Error occured "Over all!". Type: <class '__main__.AmigoException'>

# %% [markdown]
# ## assert

# %%
assert True

# %%
assert 1 == 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-e99f91a18d62> in <module>()
# ----> 1 assert 1 == 0
#
# AssertionError:

# %% [markdown]
# ## Не злоупотребляй исключениями!

# %%
# %%timeit

result = {"key": 1}

for _ in range(1000):
    try:
        res = result["bar"]
    except KeyError:
        res = 0
# Out:
# 283 µs ± 6.92 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit

result = {"key": 1}

for _ in range(1000):
    res = result.get("bar", 0)
# Out:
# 118 µs ± 10.9 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit

result = {"key": 1}

for _ in range(1000):
    res = result["bar"] if "bar" in result else 0
# Out:
# 42.3 µs ± 7.47 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # Менеджер контекста

# %%
# !rm -r tmp
# !mkdir -p tmp

# %%
# !echo "Hello, world!\n1 2 3\nTrue" > tmp/example.txt

# %%
# !cat tmp/example.txt
# Out:
# Hello, world!
# 1 2 3
# True

# %%
f_input = open('tmp/example.txt', mode='r')
try:
    for line in f_input:
        print(line, end='')
finally:
    f_input.close()
# Out:
# Hello, world!
# 1 2 3
# True

# %%
with open('tmp/example.txt', mode='r') as f_input:
    for line in f_input:
        print(line, end='')
        
f_input.closed
# Out:
# Hello, world!
# 1 2 3
# True
# True

# %%
try:
    with open('tmp/example.txt', mode='r') as f_input:
        for line in f_input:
            print(line, end='')
        raise RuntimeError('All Hands on Deck!')
except RuntimeError:
    print(f_input.closed)
    raise
# Out:
# Hello, world!
# 1 2 3
# True
# True
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-e3f012a45de4> in <module>()
#       3         for line in f_input:
#       4             print(line, end='')
# ----> 5         raise RuntimeError('All Hands on Deck!')
#       6 except RuntimeError:
#       7     print(f_input.closed)
#
# RuntimeError: All Hands on Deck!

# %%
with open('tmp/example.txt', mode='r') as f_input:
    with open('tmp/output.txt', mode='w') as f_output:
        for line in f_input:
            f_output.write(line)

# %%
# Либо с backslash-ом, либо на одной строке

with open('tmp/example.txt', mode='r') as f_input, \
    open('tmp/output.txt', mode='w') as f_output:
        for line in f_input:
            f_output.write(line)

# %%
import sys

f_input = open('tmp/example.txt', mode='r')
f_input_enter = f_input.__enter__()
try:
    for line in f_input_enter:
        print(line, end='')
finally:
    exc_type, exc_value, traceback = sys.exc_info()
    suppress = f_input.__exit__(exc_type, exc_value, traceback)
    print(exc_type, exc_value, traceback, sep=', ')
    if exc_value is not None and not suppress:
        raise exc_value
# Out:
# Hello, world!
# 1 2 3
# True
# None, None, None

# %%
import sys

f_input = open('tmp/example.txt', mode='r')
f_input_enter = f_input.__enter__()
try:
    for line in f_input_enter:
        print(line, end='')
    raise RuntimeError('All Hands on Deck!')
finally:
    exc_type, exc_value, traceback = sys.exc_info()
    suppress = f_input.__exit__(exc_type, exc_value, traceback)
    print(exc_type, exc_value, traceback, sep=', ')
    if exc_value is not None and not suppress:
        raise exc_value
# Out:
# Hello, world!
# 1 2 3
# True
# <class 'RuntimeError'>, All Hands on Deck!, <traceback object at 0x7ff5c44a9e48>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-c2ac022c3763> in <module>()
#      12     print(exc_type, exc_value, traceback, sep=', ')
#      13     if exc_value is not None and not suppress:
# ---> 14         raise exc_value
#
# <ipython-input-33-c2ac022c3763> in <module>()
#       6     for line in f_input_enter:
#       7         print(line, end='')
# ----> 8     raise RuntimeError('All Hands on Deck!')
#       9 finally:
#      10     exc_type, exc_value, traceback = sys.exc_info()
#
# RuntimeError: All Hands on Deck!

# %%
import os
import functools

from random import randrange


def random_string(size=7):
    def random_symbol():
        variants = [
            (ord('0'), ord('9')),
            (ord('a'), ord('z')),
        ]
        
        while True:
            i = randrange(0, len(variants))
            yield chr(randrange(*variants[i]))
        
    g = random_symbol()
    return ''.join(next(g) for i in range(size))


class TemporaryFile():
    def __init__(self, path='.', *args, **kwargs):
        self.name = os.path.join(path, 'tmp' + random_string(size=7))
        self.handler = functools.partial(open, *args, **kwargs)
        
    def __enter__(self):
        self._fd = self.handler(self.name)
        return self._fd
        
    def __exit__(self, exc_type, exc_value, traceback):
        # 1. Зачем проверка на закрытие?
        # 2. Зачем удалять атрибут?
        # 3. Почему можно обойтись без return?
        if not self._fd.closed:
            self._fd.close()
        del self._fd
        os.remove(self.name)
        

with TemporaryFile(path='tmp', mode='w+') as f_tmp:
    f_tmp.write('Hello world!')
    f_tmp.seek(0)
    print(f_tmp.readline())

    
open(f_tmp.name)
# Out:
# Hello world!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-d0aa3b8d31e3> in <module>()
#      45
#      46
# ---> 47 open(f_tmp.name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tmp/tmps2262ks'

# %%
import tempfile

with tempfile.NamedTemporaryFile(mode='w+') as f_tmp:
    print('tmpfile:', f_tmp.name)
    
    f_tmp.write('Hello world!')
    f_tmp.seek(0)
    print(f_tmp.readline())
# Out:
# tmpfile: /tmp/tmpo0r5l4gb
# Hello world!

# %%
class SuppressException:
    def __init__(self, exc_type):
        self.exc_type = exc_type
        
    def __enter__(self):
        pass
    
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type is not None and issubclass(exc_type, self.exc_type):
            print("Keep calm, ignore exceptions.")
            return True

# %%
with SuppressException(ZeroDivisionError):
    5 / 0
# Out:
# Keep calm, ignore exceptions.

# %%
with SuppressException(ZeroDivisionError):
    raise RuntimeError()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-77b5aff88ae3> in <module>()
#       1 with SuppressException(ZeroDivisionError):
# ----> 2     raise RuntimeError()
#
# RuntimeError:

# %%
import contextlib

with contextlib.suppress(ValueError):
    raise ValueError
