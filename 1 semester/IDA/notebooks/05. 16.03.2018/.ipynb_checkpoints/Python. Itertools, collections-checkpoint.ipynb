# %% [raw]
# Слайды Python (А.Г Дьяконов)
# https://alexanderdyakonov.wordpress.com/2016/10/12/питон-python/
#
# Слайды Pandas (А.Г Дьяконов)
# https://alexanderdyakonov.wordpress.com/2015/11/06/знакомство-с-pandas-слайды/
#
# Лекции по Python (Сергей Лебедев):
# https://compscicenter.ru/courses/python/2015-autumn/

# %% [markdown]
# # Python. Типы.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [raw]
# Базовые типы:
# 1. None
# 2. Логические (True, False)
# 3. Числовые (int, float, complex)
# 4. Изменяемые коллекции (list, set, dict)
# 5. Неизменяемые коллекции (tuple, frozenset)

# %%
a = None
b = None
print id(a) == id(b)
print id(5) == id(5)
print id(172) == id(272)
aaa = 1213123
bbb = 1213123
print id(aaa) == id(bbb)
# Out:
# True
# True
# False
# False

# %% [markdown]
# # Модуль Collections

# %% [raw]
# 1. Tuple-like (namedtuple)
# 2. List-like (deque)
# 3. Dict-like (Counter, OrderedDict, defaultdict)

# %%
from collections import namedtuple, deque, \
                        Counter, OrderedDict, \
                        defaultdict

# %% [markdown]
# # Коллекции

# %% [markdown]
# ## Базовые методы

# %% [raw]
# len - длина коллекции
# elem in collection, elem not in collection # разная сложность операций для разных collection
# del - удаление элемента

# %%
print tuple(), (), (1,), (1,)*3
print list(), [1] * 2, [[]] * 2
print set()
print dict(), {}
# Out:
# () () (1,) (1, 1, 1)
# [] [1, 1] [[], []]
# set([])
# {} {}

# %%
a = [1, 2, 3, 4, 5]
del a[1]
print a
print 1 in a, 2 in a, 'asd' in a
# Out:
# [1, 3, 4, 5]
# True False False

# %%
d = {'key_1': 1, 'key_2': 2}
del d['key_1']
print d
print 'key_2' in d, 2 in d
# Out:
# {'key_2': 2}
# True False

# %% [markdown]
# ## Изменяемые vs Неизменяемые

# %%
# Изменяемые (list, set, dict, deque, Counter, OrderedDict, defaultdict)

lst = [1, 2, 3]
prev_id = id(lst)
print lst
lst += [4]  # lst.append(4)
new_id = id(lst)
print lst
print 'Has id changed (list)?', prev_id != new_id

print '-' * 100

# Неизменяемые (tuple, namedtuple)
tpl = (1, 2, 3)
prev_id = id(tpl)
print tpl
tpl += (4,)  # Запятая нужна! (4) — просто число в скобках
print tpl
new_id = id(tpl)
print 'Has id changed (tuple)?', prev_id != new_id
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]
# Has id changed (list)? False
# ----------------------------------------------------------------------------------------------------
# (1, 2, 3)
# (1, 2, 3, 4)
# Has id changed (tuple)? True

# %% [markdown]
# ## Сложность
# https://wiki.python.org/moin/TimeComplexity

# %% [markdown]
# # Tuple

# %%
# http://stackoverflow.com/questions/6153348/time-complexity-of-tuple-in-python
profile = (1, 'Pavel', 'Durov', 1984, 'Telegram')

# %%
name = profile[1:3]

# %%
name
# Out:
# ('Pavel', 'Durov')

# %%
NAME_SLICE = slice(1, 3)

# %%
print profile[NAME_SLICE]
# Out:
# ('Pavel', 'Durov')

# %% [markdown]
# # Namedtuple

# %%
from collections import namedtuple
fiels = ['vk_id', 'name', 'surname', 'year', 'work']
VkProfile = namedtuple('VkProfile', fiels)

# %%
profile_nt = VkProfile(vk_id=1, name='Pavel', 
                       surname='Durov', 
                       year=1984, 
                       work='Telegram')

# %%
profile_nt.name, profile_nt.surname
# Out:
# ('Pavel', 'Durov')

# %%
profile_nt._replace(work='new job')
# Out:
# VkProfile(vk_id=1, name='Pavel', surname='Durov', year=1984, work='new job')

# %%
profile_nt._asdict()
# Out:
# OrderedDict([('vk_id', 1),
#              ('name', 'Pavel'),
#              ('surname', 'Durov'),
#              ('year', 1984),
#              ('work', 'Telegram')])

# %% [markdown]
# # List

# %% [markdown]
# ## Базовые операции

# %%
a = ['start']

# Добавление одного элемента в конец списка
a.append(1)  # O(1)
print a
# Out:
# ['start', 1]

# %%
# Добавление k элементов в конец списка
a.extend([2, 3])  # O(k)
print a
# Out:
# ['start', 1, 2, 3]

# %%
# Доступ к элементу по индексу
print a[0]  # O(1)
# Out:
# start

# %%
# Вставка элемента внутрь списка
a.insert(2, 'new_element')  # O(n)
print a
# Out:
# ['start', 1, 'new_element', 2, 3]

# %%
# Удаление элемента из списка по индексу
ret = a.pop(1)  # O(n) - с вовзращением элемента
print ret, a
del a[1]  # O(n) - без вовзращения элемента
print ret, a
# Out:
# 1 ['start', 'new_element', 2, 3]
# 1 ['start', 2, 3]

# %%
# Сортировка https://en.wikipedia.org/wiki/Timsort
print sorted(a)  # без изменения исходного списка
print a
a.sort()  # с изменением исходного списка
print a
# Out:
# [2, 3, 'start']
# ['start', 2, 3]
# [2, 3, 'start']

# %%
# Наличие элемента в списке
'start' in a  # O(n) !!!
# Out:
# True

# %% [markdown]
# ## Особенности копирования

# %% [markdown]
# ### Как не работает?

# %%
x = [[0]] * 2
x
# Out:
# [[0], [0]]

# %%
x[0][0] = 1
x
# Out:
# [[1], [1]]

# %%
id(x[0]) == id(x[1])
# Out:
# True

# %%
y = x + x
y
# Out:
# [[1], [1], [1], [1]]

# %%
y[0][0] = 2
y
# Out:
# [[2], [2], [2], [2]]

# %% [markdown]
# ### А как работает?

# %%
x = [[0] for x in xrange(2)]
print x
x[0][0] = 1
print x
# Out:
# [[0], [0]]
# [[1], [0]]

# %% [markdown]
# ### Как скопировать список?

# %%
x = [1, 2, 3]
y = x
id(x) == id(y)
# Out:
# True

# %%
y = x[:]
print 'y=x[:]', id(x) == id(y)

y = list(x)
print 'y=list(x)', id(x) == id(y)

from copy import copy
y = copy(x)
print 'y=copy(x)', id(x) == id(y)
# Out:
# y=x[:] False
# y=list(x) False
# y=copy(x) False

# %%
x = [[1, 2], [3, 4]]

# %%
y = x[:]
print 'y=x[:]', id(x[0]) == id(y[0])

y = list(x)
print 'y=list(x)', id(x[0]) == id(y[0])

from copy import copy
y = copy(x)
print 'y=copy(x)', id(x[0]) == id(y[0])
# Out:
# y=x[:] True
# y=list(x) True
# y=copy(x) True

# %%
from copy import deepcopy
y = deepcopy(x)
print id(x[0]) == id(y[0])
# Out:
# False

# %% [markdown]
# # Deque

# %%
from collections import deque

# %%
deq = deque([1, 2, 3])

# %%
deq.append(100)  # O(1)
print deq
# Out:
# deque([1, 2, 3, 100])

# %%
deq.appendleft(-7)  # O(1)
print deq
# Out:
# deque([-7, 1, 2, 3, 100])

# %%
# Добавление и удаление элемента с обеих сторон очереди работает за константное время.
# Но нет slice! 
deq[1:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-7cfbf93f23bc> in <module>()
#       1 # Добавление и удаление элемента с обеих сторон очереди работает за константное время.
#       2 # Но нет slice!
# ----> 3 deq[1:3]
#
# TypeError: sequence index must be integer, not 'slice'

# %% [markdown]
# ### Очереди с ограниченной длинной можно создать с помощью параметра max_len
# deq = deque([1, 2, 3], maxlen=3)

# %% [markdown]
# # Множества (set, frozenset)

# %% [markdown]
# ### Общее frozenset и set

# %% [markdown]
# ### В Python — это хеш-сет, то есть оно может содержать только элементы, которые можно захешировать (неизменяемые типы - хешируемые, изменяемые - нет)

# %%
{(2, 3)} # если нет ':', то это set
# Out:
# {(2, 3)}

# %%
{[2, 3]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-39f49da4f433> in <module>()
# ----> 1 {[2, 3]}
#
# TypeError: unhashable type: 'list'

# %%
{set(), set()}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-80e808a7aa28> in <module>()
# ----> 1 {set(), set()}
#
# TypeError: unhashable type: 'set'

# %%
{frozenset(), frozenset()}
# Out:
# {frozenset()}

# %%
elems = {1, 2, 'py'}

# %%
print 1 in elems  # O(1) !!! 
print 'py' in elems  # O(1) !!!
# Out:
# True
# True

# %%
# Объединение
print elems.union({1, 4})
print elems | {1, 4}
# Out:
# set([1, 2, 'py', 4])
# set([1, 2, 'py', 4])

# %%
# Пересечение
print elems.intersection({1, 4})
print elems & {1, 4}
# Out:
# set([1])
# set([1])

# %%
# Разность
print elems.difference({1, 4})
print elems - {1, 4}
# Out:
# set([2, 'py'])
# set([2, 'py'])

# %%
# Вложения
a = {1, 2, 3}
b = {2, 3}
print a >= b
print a > b
print a < b
# Out:
# True
# True
# False

# %% [markdown]
# ### Только set

# %%
# Добавление
a.add(5)
a.update([1, 5])
# Удаление
a.remove(5) # remove удаляет из множества существующий элемент или 
            # поднимает исключение, если элемент во множестве не содержится
a.discard(5) # discard удаляет элемент, только если он содержится во множестве

# %% [markdown]
# # Словари

# %%
d = {'a': 1, 'b': 2, 'c': 5, 'd': 'yes'}
d = dict(a=1, b=2, c=5, d='yes')

# %%
# Проверка наличия ключа в словаре
'a' in d  # O(1) !!!
# Out:
# True

# %%
key = 'default'
default_val = 'default'
# Следующее равносильно
print d[key] if key in d else default_val # эти две записи
print d.get(key, default_val)             # эквивалентны
print d[key]
# Out:
# default
# default
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-7354ac12d50c> in <module>()
#       4 print d[key] if key in d else default_val # эти две записи
#       5 print d.get(key, default_val)             # эквивалентны
# ----> 6 print d[key]
#
# KeyError: 'default'

# %%
print d.keys()
print d.values()
print d.items()
# в третьем питоне есть iter... версии этих методов
# Out:
# ['a', 'c', 'b', 'd']
# [1, 5, 2, 'yes']
# [('a', 1), ('c', 5), ('b', 2), ('d', 'yes')]

# %%
# Добавление в словарь
d['z'] = 0
print d
d.update({'y': -1, 'w': -2})
print d
# Out:
# {'a': 1, 'c': 5, 'b': 2, 'd': 'yes', 'z': 0}
# {'a': 1, 'c': 5, 'b': 2, 'd': 'yes', 'w': -2, 'y': -1, 'z': 0}

# %%
# Удаление из словаря
del d['a']

# %%
for k in d:  # тоже самое, что и d.keys()
    print k, d[k]
# Out:
# c 5
# b 2
# d yes
# w -2
# y -1
# z 0

# %%
# Объединение словарей без их изменения
dct1 = {'a':1, 'b':2}
dct2 = {'b':3, 'c':4}
union = dct1.copy()
union.update(dct2)
print(union, dct1, dct2)

dct1 = {'a':1, 'b':2}
dct2 = {'b':3, 'c':4}
union  = dict(dct1, **dct2)  # про ** будет чуть позже
print(union, dct1, dct2)
# Out:
# ({'a': 1, 'c': 4, 'b': 3}, {'a': 1, 'b': 2}, {'c': 4, 'b': 3})
# ({'a': 1, 'c': 4, 'b': 3}, {'a': 1, 'b': 2}, {'c': 4, 'b': 3})

# %%
# в Python нет switch, но есть словари) 
def fail_func():
    print('Fail')
    
def success_func():
    print('Success')
    
cases = {'case_1': fail_func, 'case_2': success_func}

cases['case_2']()
# Out:
# Success

# %% [markdown]
# ## OrderedDict

# %%
from collections import OrderedDict
# словарь с ключами, упорядоченными по времени добавления
# Изменение значения по ключу не влияет на порядок ключей в словаре

# %% [markdown]
# ## Counter

# %%
from collections import Counter

# %%
cnt = Counter([1, 1, 2, 1, 3])
cnt
# Out:
# Counter({1: 3, 2: 1, 3: 1})

# %%
cnt[0] += 1  # Нет ошибки !!!
cnt
# Out:
# Counter({0: 1, 1: 3, 2: 1, 3: 1})

# %%
cnt.most_common(2)
# Out:
# [(1, 3), (0, 1)]

# %%
c1 = Counter(foo=4, bar=-1) 
c2 = Counter(foo=2, bar=2)
print c1 + c2 # c1[k] + c2[k]
print c1 - c2 # c1[k] - c2[k]
print c1 & c2 # min(c1[k], c2[k])
print c1 | c2 # max(c1[k], c2[k])
# Out:
# Counter({'foo': 6, 'bar': 1})
# Counter({'foo': 2})
# Counter({'foo': 2})
# Counter({'foo': 4, 'bar': 2})

# %% [markdown]
# # Упаковка и распаковка

# %%
def _max(x, y):
    if x > y:
        return x
    return y

# %%
_max(2, 3), _max(3, 2)
# Out:
# (3, 3)

# %%
def _max(*args):
    print 'args:', args
    max_x = float('-inf')
    for x in args:
        if x > max_x:
            max_x = x
    return max_x

# %%
_max(3, 1, 100, -2)
# Out:
# args: (3, 1, 100, -2)
# 100

# %%
lst = [3, 1, 100, -2]
_max(*lst)
# Out:
# args: (3, 1, 100, -2)
# 100

# %%
def return_x(**kwargs):
    print 'kwargs:', kwargs
    return kwargs.get('x')

# %%
return_x({'x': 100, 'y': 50})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-280666a08ce1> in <module>()
# ----> 1 return_x({'x': 100, 'y': 50})
#
# TypeError: return_x() takes exactly 0 arguments (1 given)

# %%
return_x(**{'x': 100, 'y': 50})
# Out:
# kwargs: {'y': 50, 'x': 100}
# 100

# %%
return_x(x=10, y=23)
# Out:
# kwargs: {'y': 23, 'x': 10}
# 10

# %% [markdown]
# # Itertools

# %%
it = iter(xrange(7))

print (next(it))
print (next(it))
print ([x for x in it])

 
print (next(it))
# Out:
# 0
# 1
# [2, 3, 4, 5, 6]
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-79-e535191d936c> in <module>()
#       6
#       7
# ----> 8 print (next(it))
#
# StopIteration:

# %%
a = iter([1, 2, 3])
b = iter([4, 5])
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-8a35f6a4d6e9> in <module>()
#       1 a = iter([1, 2, 3])
#       2 b = iter([4, 5])
# ----> 3 a + b
#
# TypeError: unsupported operand type(s) for +: 'listiterator' and 'listiterator'

# %%
# Объединение итераторов
from itertools import chain
for x in chain(a, b):
    print x
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list(a), list(b)
# Out:
# ([], [])

# %%
# Срезы
from itertools import islice
a = iter([1, 2, 3])
b = iter([4, 5])

for x in islice(a, 1, 3):
    print x
# Out:
# 2
# 3

# %%
# перестановки
from itertools import permutations
print list(permutations('AB'))
# Out:
# [('A', 'B'), ('B', 'A')]

# %%
# сочетания без повторений
from itertools import combinations
list(combinations('ABC', 2))
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'C')]

# %%
# сочетания c повторениями
from itertools import combinations_with_replacement
list(combinations_with_replacement('ABC', 2))
# Out:
# [('A', 'A'), ('A', 'B'), ('A', 'C'), ('B', 'B'), ('B', 'C'), ('C', 'C')]

# %%
# декартово произведение
from itertools import product

# Например, когда не знаешь глубину вложенного цикла
n = 3
cycles = [
    [1, 2],
    [3, 4],
    [5, 6]
]
for indecies in product(*cycles):
    print indecies
# Out:
# (1, 3, 5)
# (1, 3, 6)
# (1, 4, 5)
# (1, 4, 6)
# (2, 3, 5)
# (2, 3, 6)
# (2, 4, 5)
# (2, 4, 6)

# %% [markdown]
# ### GroupBy

# %%
# данные key - value
from itertools import groupby
data = [
    ('Factory A', 'day 1', 100),
    ('Factory B', 'day 1', 200),
    ('Factory C', 'day 1', 300),
    
    ('Factory A', 'day 2', 175),
    ('Factory B', 'day 2', 115),
    ('Factory C', 'day 2', 100),
    
    ('Factory A', 'day 3', 500),
    ('Factory B', 'day 3', 800),
    ('Factory C', 'day 3', 1000)
]

# %%
# Сколько товара все фабрики произвели за каждый день
for (key, values) in groupby(data, lambda x: x[1]):
    print key, values
# Out:
# day 1 <itertools._grouper object at 0x105fdfad0>
# day 2 <itertools._grouper object at 0x105fdfe90>
# day 3 <itertools._grouper object at 0x105fdfc50>

# %%
for (key, values) in groupby(data, lambda x: x[1]):
    s = 0
    for v in values:
        s += v[2]
    print key, s
# Out:
# day 1 600
# day 2 390
# day 3 2300

# %%
for (key, values) in groupby(data, lambda x: x[1]):
    print key, sum([v[2] for v in values])
# Out:
# day 1 600
# day 2 390
# day 3 2300

# %%
# Сколько каждая фабрика произвела за все дни
for (key, values) in groupby(data, lambda x: x[0]):
    print key, sum([v[2] for v in values])
# Out:
# Factory A 100
# Factory B 200
# Factory C 300
# Factory A 175
# Factory B 115
# Factory C 100
# Factory A 500
# Factory B 800
# Factory C 1000

# %%
data = sorted(data)

# %%
data
# Out:
# [('Factory A', 'day 1', 100),
#  ('Factory A', 'day 2', 175),
#  ('Factory A', 'day 3', 500),
#  ('Factory B', 'day 1', 200),
#  ('Factory B', 'day 2', 115),
#  ('Factory B', 'day 3', 800),
#  ('Factory C', 'day 1', 300),
#  ('Factory C', 'day 2', 100),
#  ('Factory C', 'day 3', 1000)]

# %%
for (key, values) in groupby(data, lambda x: x[0]):
    print key, sum([v[2] for v in values])
# Out:
# Factory A 775
# Factory B 1115
# Factory C 1400

# %% [markdown]
# # Задания

# %% [raw]
# GroupBy
# 0. Загрузите titanic dataset
# 1. Выясните среднюю стоимость (Fare) для каждого из классов (с помощью groupby в pandas)
# 2. Сделайте тоже самое, но уже с помощью groupby из itertools
#
# Permutations
# 4. Посчитайте число перестановок из n элементов (n=2..7), в которых ни один элемент не находится на своем изначальном месте.
#
# Collections
# 5. Посчитайте частоты триграмм в тексте.
# В качестве текста возьмем имена и фамилии из titanic dataset (text = ' '.join(data.Name.str.lower().values)).
