# %% [markdown]
# # Автоматическое определение языка текста

# %%
import argparse
import codecs
import unicodedata
import operator

import nltk
import numpy

from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn.metrics import roc_curve, auc
from sklearn.feature_extraction import DictVectorizer
from sklearn.naive_bayes import MultinomialNB
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Будем решать задачу определения языка печатного текста. В файле `europarl.test.txt` содержатся записи депатов в Европарламенте. Каждая строка содержит код языка и высказывание на этом языке, например, на болгарском:
#
# `bg	(DE) Г-н председател, след повече от 300 години колониално управление и след като континентът се превърна в арена на Студената война, днес Латинска Америка вече е един от нововъзникващите региони в света.`
#
# Код языка будет целевой переменной, а из высказывания нам предстоит извлечь признаки.
#
# Один из возможных подходов состоит в том, чтобы в качестве признаков использовать тройки из подряд идущих символов, встречающихся в словах. Предположение состоит в том, что для каждого языка список наиболее популярных троек более-менее уникален. Попробуем проверить это предположение.
#
# Комм.: в данном случае: документ — высказывание

# %% [markdown]
# ## Считывание данных

# %%
DS_PATH = "./europarl.test.txt" # Path to the data file
N_GRAM = 3 # Extract symbol sequences of length N
TOP_TOKENS = 10 # Number of top selected n-grams for each language

# %%
def read_documents(data_path):
    """
    Reads a sequence of documents from the text file
    located on a given path.

    Returns:
        A generator of tuples (LANG_CODE, unicode)
    """
    with codecs.open(data_path, 'rU', "utf-8") as data_file:
        for line in data_file:
            lang, doc = line.strip().split('\t')
            yield lang, doc

# %%
def normalise_document(doc):
    """
    Convert document to lower-case and remove accents
    
    Returns:
        A normalised document as unicode
    """
    return ''.join(c for c in unicodedata.normalize('NFD', doc.lower()) if not unicodedata.combining(c))

# %%
def tokenize_document(doc, n):
    """
    Split document in N-Grams
    
    TODO: implement this

    Returns:
        Iterable (generator or list) of unicode n-grams
    """
    tokenizer = nltk.WordPunctTokenizer()
    for token in tokenizer.tokenize(doc):
        if len(token) >= n:
            for ngram in nltk.ngrams(token, n):
                yield u"".join(ngram)

list(tokenize_document('kweqlwurg we ewroiwehriweq lapw', 3))
# Out:
# [u'kwe',
#  u'weq',
#  u'eql',
#  u'qlw',
#  u'lwu',
#  u'wur',
#  u'urg',
#  u'ewr',
#  u'wro',
#  u'roi',
#  u'oiw',
#  u'iwe',
#  u'weh',
#  u'ehr',
#  u'hri',
#  u'riw',
#  u'iwe',
#  u'weq',
#  u'lap',
#  u'apw']

# %% [markdown]
# Первым делом нам необходимо зачитать данные из файла. Будем читать 3 структуры данных:
#
# - docs - список словарей, каждый из которых соответствует одному документу и содержит количество вхождений для каждой n-граммы (токена)
# - langs - список, содержащий классы докуметов (каждому коду языка соответствует числовой класс)
# - lang_freq - словарь, который нужен для подсчета ниболее популярных n-грам для каждого языка. Элементы этого словаря: код языка -> (id класса, частоты n-грам (аналогично docs))
#
# Для того, чтобы заработал код, зачитывающий данные, необходимо (до) реализовать функции, перечисленные выше.

# %%
# A list of dicts, each representing one document in format:
# {token: count1, ...}
docs = []
# Language code for each dict (0-based)
langs = []
# A list of tuples, each tuple corresponds to one language
# First compunent is the code of the language, second is its token frequencies
# Contains entries like {lang_code: (lang_id, {token_frequencies})}
lang_freq = {}

for lang, doc in read_documents(DS_PATH):
    normalized_doc = normalise_document(doc)

    token_freq = {}
    for token in tokenize_document(normalized_doc, N_GRAM):
        token_freq[token] = 1 + token_freq.get(token, 0)
        if lang not in lang_freq:
            print("Found language %s: %d" % (lang, len(lang_freq)))
            lang_freq[lang] = (len(lang_freq), {})
        lang_freq[lang][1][token] = 1 + lang_freq[lang][1].get(token, 0)

    docs.append(token_freq)
    langs.append(lang_freq[lang][0])
# Out:
# Found language bg: 0
# Found language cs: 1
# Found language da: 2
# Found language de: 3
# Found language el: 4
# Found language en: 5
# Found language es: 6
# Found language et: 7
# Found language fi: 8
# Found language fr: 9
# Found language hu: 10
# Found language it: 11
# Found language lt: 12
# Found language lv: 13
# Found language nl: 14
# Found language pl: 15
# Found language pt: 16
# Found language ro: 17
# Found language sk: 18
# Found language sl: 19
# Found language sv: 20

# %%
for k, v in docs[0].iteritems():
    print u'{} {}'.format(k, v)
# Out:
# ира 1
# кон 1
# рат 1
# ара 1
# кур 1
# тар 1
# тен 1
# нов 1
# уре 1
# иза 1
# ста 1
# арт 1
# ват 1
# тир 1
# рти 1
# вро 1
# 202 1
# евр 1
# роп 1
# рен 1
# ато 1
# при 1
# ати 1
# тиз 1
# мар 1
# бва 1
# 020 1
# тон 1
# аци 1
# рив 1
# изх 1
# зхо 1
# тря 1
# ряб 1
# ход 1
# ябв 1
# нку 1
# нте 1
# ент 1
# онк 1
# ция 1
# зац 1
# опа 1
# ива 1

# %%
for k, v in lang_freq['bg'][1].iteritems():
    print k, v
# Out:
# рне 11
# бли 38
# рна 30
# бло 3
# опъ 17
# рно 74
# бла 53
# опр 33
# sco 1
# бле 50
# опу 7
# nwe 1
# фек 19
# щое 1
# фев 3
# фед 1
# псв 2
# мии 1
# aud 1
# лаб 5
# пса 8
# мюс 2
# пок 28
# пол 185
# пои 4
# иня 8
# поо 6
# поп 8
# пом 75
# пон 22
# пов 50
# пог 8
# пож 25
# поз 39
# под 215
# пое 7
# гъл 3
# пош 1
# пощ 1
# поя 1
# гън 1
# пот 41
# рни 39
# пор 111
# пос 136
# поч 19
# пох 2
# мюн 1
# лаи 3
# опт 1
# вож 1
# мво 1
# лак 1
# тфо 2
# тюн 1
# фер 11
# фес 4
# щот 36
# лан 53
# блъ 2
# опо 14
# опи 22
# блю 13
# опл 9
# опе 223
# рня 1
# опа 103
# днъ 5
# тле 2
# инн 6
# lvi 1
# тло 1
# тли 11
# лат 38
# зих 1
# зиц 16
# зич 2
# зир 20
# зис 39
# зит 6
# мня 7
# анч 1
# рьо 1
# зия 9
# щож 1
# сюл 2
# наз 10
# над 42
# нае 18
# нав 27
# наг 14
# наб 22
# нао 1
# нап 83
# нам 43
# нан 61
# нак 26
# нал 83
# наи 74
# цял 23
# смя 12
# аши 28
# смъ 2
# ашн 10
# лащ 7
# ашв 1
# аша 18
# ner 1
# nes 1
# аше 20
# sli 1
# сми 10
# ашт 3
# сме 57
# mei 1
# сма 1
# нац 26
# нач 90
# наф 1
# нах 9
# нат 215
# нау 13
# нар 48
# нас 124
# ная 7
# инг 5
# 107 1
# наш 46
# мни 7
# зие 3
# зиз 1
# мно 81
# зиг 3
# мна 4
# зин 8
# зио 2
# зии 1
# мне 12
# зик 8
# зил 4
# яза 3
# язв 8
# езк 1
# ези 80
# езп 3
# езо 34
# езн 6
# вчи 2
# езв 3
# еза 27
# гля 1
# езе 13
# езд 3
# свр 1
# лка 4
# bri 1
# тъп 55
# свъ 33
# лко 50
# тък 12
# тъи 24
# ъжд 13
# кеа 1
# кед 3
# ткл 1
# южн 4
# кеп 3
# кем 4
# кен 2
# ято 56
# шру 1
# ятн 8
# яти 19
# яте 17
# ята 294
# ужн 3
# rla 1
# nke 1
# nkf 1
# дже 25
# ужд 23
# уже 8
# ужв 2
# джа 1
# ужа 7
# ятс 4
# кет 10
# кер 1
# аус 2
# идв 1
# тъч 11
# тъц 3
# свд 1
# све 51
# тър 52
# сви 7
# сво 47
# тъш 2
# ице 8
# езщ 2
# дво 5
# езу 18
# езс 1
# езр 9
# eri 2
# лте 7
# изо 25
# изп 65
# изм 43
# изн 24
# изк 43
# изл 13
# изи 50
# изд 4
# изе 3
# изв 73
# изг 19
# иза 65
# изб 24
# гъв 2
# ens 1
# hop 1
# enw 1
# yal 1
# чкв 1
# lan 2
# ощя 1
# lad 1
# laf 1
# lac 1
# изя 7
# изъ 19
# изш 1
# изц 7
# lau 1
# lav 1
# изх 6
# изт 16
# изр 19
# изс 17
# икц 1
# еду 10
# длъ 4
# уин 1
# mps 1
# итн 2
# ъко 8
# ъжи 3
# зри 2
# ъки 2
# зре 8
# зра 42
# ъкв 3
# ъка 9
# ima 1
# итк 1
# cla 1
# imo 1
# ssa 1
# оск 3
# зче 3
# роя 16
# рос 103
# рор 3
# роу 5
# рот 34
# роф 8
# роч 10
# роц 31
# рои 36
# рол 22
# рок 18
# рон 4
# ром 41
# роп 263
# роб 47
# щни 2
# рог 26
# ров 41
# рое 16
# род 89
# роз 16
# ита 107
# ъже 8
# итв 9
# den 1
# вкл 32
# мяв 1
# шаи 1
# шан 2
# шав 29
# чли 1
# жби 5
# мян 11
# рат 135
# рас 36
# бде 1
# рач 11
# рац 40
# рах 10
# раф 22
# ращ 5
# раш 8
# рая 9
# ehl 1
# омб 4
# ома 22
# омв 1
# оме 53
# рса 2
# оми 208
# омн 13
# омп 12
# омо 58
# гаш 4
# гащ 5
# ont 3
# тия 39
# kir 1
# гар 36
# тир 46
# гат 75
# тит 93
# тих 3
# тиф 7
# тич 66
# тиц 13
# тии 5
# тил 6
# гал 7
# тин 46
# тим 24
# тип 2
# тиб 1
# тиг 40
# тив 91
# тие 40
# тид 1
# тиз 6
# газ 10
# омс 1
# омр 1
# ому 2
# nte 3
# омя 6
# раг 11
# рав 294
# раб 87
# раз 286
# раж 69
# рае 14
# рад 63
# рал 28
# рак 32
# раи 28
# ath 2
# рам 70
# мят 12
# мяр 1
# мяс 7
# ats 1
# ащо 48
# isl 1
# аща 24
# шат 20
# isa 2
# шар 1
# шах 1
# оящ 18
# сут 2
# сус 3
# сур 7
# асб 1
# 009 13
# юзъ 1
# 198 1
# мон 14
# зли 32
# 008 7
# мои 4
# мол 7
# мок 27
# мое 4
# мод 8
# моз 1
# мож 116
# моб 10
# мог 57
# зет 5
# ежъ 2
# зер 7
# зец 1
# tob 1
# ежц 1
# ютю 1
# ежи 12
# ежк 4
# ежн 2
# зел 4
# зек 1
# ежд 121
# еже 9
# зен 13
# зем 24
# учи 11
# моя 8
# злъ 1
# мощ 30
# лна 79
# лно 170
# учв 6
# мос 18
# мор 14
# лни 116
# юза 8
# ква 81
# кво 22
# кви 12
# сув 45
# суб 8
# суа 4
# суд 1
# тис 11
# сум 2
# rag 1
# rad 1
# ляк 1
# апъ 16
# лям 32
# ran 1
# ущъ 1
# ляг 1
# ляв 32
# апт 1
# апу 2
# апр 56
# ърш 25
# ъръ 2
# ърс 7
# ърт 6
# ърх 41
# ърч 23
# ърц 3
# tes 1
# сба 1
# бни 13
# сбл 15
# kes 1
# шим 6
# гир 6
# иав 1
# гис 6
# щае 1
# nel 1
# гиу 1
# сбу 1
# ъри 1
# ърл 10
# ърк 4
# ърн 13
# ърп 4
# ърб 4
# ъра 6
# ърг 28
# ърв 37
# ърд 16
# ърз 46
# ърж 123
# апо 16
# doy 1
# апл 9
# апи 2
# лят 14
# дзо 4
# апа 23
# ляц 1
# тна 41
# тне 3
# тни 97
# тно 176
# зот 1
# нее 1
# зор 5
# зос 1
# зоч 2
# сше 2
# nea 1
# иаз 1
# еро 14
# чет 26
# чес 160
# ерн 26
# ерк 37
# ерл 5
# ери 80
# рък 13
# ръз 24
# ере 48
# ерв 13
# ерг 26
# ера 46
# ерб 1
# вци 1
# сох 3
# соц 29
# соч 34
# сор 1
# сот 1
# орч 1
# аци 155
# ацл 1
# чле 105
# ияе 1
# соб 37
# сов 51
# дце 1
# сом 1
# сон 3
# сок 23
# сол 15
# чев 6
# нре 1
# ръщ 12
# чел 1
# ръч 5
# ръц 4
# ерт 36
# еру 1
# чен 98
# ерс 10
# зов 24
# зог 1
# bat 1
# зоб 10
# bar 1
# зод 1
# szy 1
# зол 18
# зоп 14
# зон 14
# яем 2
# bal 1
# тнь 20
# кръ 1
# nut 2
# утв 1
# ута 4
# утб 1
# rtm 1
# ути 1
# уто 1
# цаи 1
# утн 1
# mut 1
# лик 30
# тяс 2
# лим 28
# лин 5
# mus 1
# лип 10
# лиа 11
# либ 5
# лив 19
# лиг 6
# лид 12
# вна 45
# лиж 16
# лиз 37
# лът 5
# ддъ 4
# лър 1
# лъс 2
# лъч 1
# ярв 3
# ярн 4
# ддс 1
# удя 1
# кзе 1
# ярк 1
# уде 5
# уда 8
# удв 6
# мля 1
# лък 1
# удн 33
# удо 9
# итъ 3
# уди 4
# лъп 1
# удл 1
# лиш 5
# лищ 3
# баз 3
# eli 1
# лия 44
# лир 20
# лис 25
# лит 128
# лиф 8
# лих 2
# лиц 20
# лич 78
# утр 7
# ile 1
# 27х 1
# цат 18
# ill 1
# хин 1
# итр 3
# кри 71
# кро 10
# кра 82
# кре 113
# гие 4
# бег 5
# млр 2
# дбу 1
# 250 1
# гик 2
# ару 11
# fra 2
# ъхд 1
# ием 38
# иен 7
# беж 4
# fro 3
# арс 4
# дуп 4
# kon 1
# аме 254
# тап 7
# амб 5
# ама 33
# амп 2
# амо 60
# joh 1
# амк 22
# ами 30
# улс 2
# зид 5
# амр 1
# ткр 5
# бем 2
# иеф 1
# иех 3
# иер 3
# иет 135
# ъхъ 1
# xxi 1
# дам 11
# гац 4
# зив 4
# шеи 1
# зим 6
# elt 1
# sla 1
# бсе 2
# 073 1
# ... 1
# бсо 5
# бси 4
# бсл 2
# бск 2
# лац 3
# ара 88
# ъмн 6
# схо 2
# арж 2
# оян 13
# иев 1
# шет 9
# оял 2
# гоб 2
# рхо 6
# ояв 8
# рму 3
# тко 5
# бдя 1
# рме 2
# чна 27
# рма 39
# рмо 6
# жба 2
# лаш 1
# рми 19
# арн 30
# оях 1
# тки 5
# чне 4
# оят 84
# нзи 4
# зця 7
# thy 1
# млн 4
# бст 20
# the 2
# 800 1
# tha 1
# бсъ 8
# жък 2
# осм 3
# лаф 1
# дяв 13
# вче 2
# реч 13
# hal 1
# сят 7
# ell 1
# сящ 2
# езг 2
# оон 5
# гот 26
# мла 4
# гор 14
# гос 53
# ris 1
# eur 3
# har 2
# elv 1
# ткъ 1
# ооб 6
# боб 2
# гоз 1
# год 49
# ебл 2
# гов 158
# гог 2
# оощ 4
# тка 16
# гоп 3
# гок 1
# гол 41
# оор 5
# ope 1
# сяг 7
# сяв 2
# сян 5
# сяк 8
# нба 1
# фтя 1
# eez 1
# чко 9
# аче 68
# ачв 1
# чки 69
# ачо 1
# ачн 9
# ачк 4
# ачи 57
# оуч 7
# сни 25
# ole 1
# сно 166
# сна 17
# olk 1
# сне 5
# мци 2
# няк 46
# боч 7
# olv 1
# ням 37
# няв 33
# лки 11
# бос 3
# вши 3
# ich 2
# зсъ 1
# тъл 5
# ice 1
# еиц 4
# ядк 1
# дящ 6
# еит 2
# ядн 1
# ядо 2
# еис 266
# яда 1
# свя 7
# еиз 5
# боя 1
# ача 28
# еиб 3
# ядр 1
# дар 39
# еин 30
# юже 3
# дят 5
# ухо 4
# ухм 3
# дяс 1
# obi 1
# нят 6
# юби 3
# нях 2
# чка 18
# сня 9
# дях 3
# деи 79
# цин 7
# анц 10
# дел 65
# дем 55
# ден 84
# ант 37
# зан 54
# деб 5
# дев 1
# дег 1
# анш 1
# мет 43
# деж 5
# son 2
# лба 3
# цио 43
# ъту 5
# ътр 31
# ътя 8
# вст 4
# тац 5
# мех 9
# меч 1
# ксп 2
# кси 10
# зае 28
# wat 1
# кст 12
# ксу 4
# заб 25
# сгр 1
# дял 2
# цив 3
# еад 1
# ижи 5
# ъте 1
# иот 1
# ижа 14
# ътн 7
# ижв 1
# иже 14
# ижд 6
# ъти 6
# анд 34
# ане 433
# зще 2
# ана 89
# анв 5
# дея 4
# дер 13
# дес 10
# ано 57
# ани 353
# анк 11
# 150 1
# нян 1
# иик 1
# алш 1
# иин 13
# джо 1
# oly 1
# джи 1
# жах 1
# ънш 6
# хит 1
# ужи 7
# рлу 1
# ънр 1
# зст 13
# вас 6
# вар 22
# ват 240
# вах 23
# бря 11
# вац 4
# ващ 58
# ваш 13
# жар 1
# бри 28
# вав 14
# бро 25
# вад 3
# важ 65
# ваи 3
# вал 20
# вак 7
# хър 1
# вам 123
# хът 2
# бре 25
# ъни 2
# зсм 1
# хив 1
# хиг 2
# хиб 1
# зсе 2
# ужб 6
# хил 4
# esa 1
# иит 38
# иис 6
# иир 1
# вша 1
# ког 40
# ков 32
# коб 1
# cot 1
# коз 3
# кое 69
# код 1
# кол 84
# кок 3
# oss 1
# кои 223
# коп 9
# коо 5
# кон 199
# ком 145
# ящо 5
# lli 1
# oso 1
# ящи 7
# ебс 1
# osc 1
# ros 2
# llg 1
# lle 1
# яща 11
# яди 2
# ver 1
# vez 1
# едв 76
# еда 126
# едб 6
# еде 71
# едл 67
# еди 134
# едо 68
# едп 46
# едм 16
# едн 122
# сва 7
# едр 1
# едс 162
# еир 1
# лку 3
# едъ 8
# едя 1
# сце 3
# мит 31
# тът 43
# dio 1
# gue 1
# gud 1
# взи 3
# ers 1
# ехв 3
# тча 1
# кот 47
# кос 23
# кор 28
# дба 2
# тче 1
# кох 2
# тчи 2
# ъдр 1
# коя 55
# лбо 8
# dis 1
# имп 1
# имо 42
# имн 4
# ими 30
# име 54
# имв 1
# имб 1
# има 148
# агл 2
# аги 15
# аго 25
# агм 1
# агн 1
# ага 67
# аге 8
# оря 16
# луж 17
# унк 6
# луг 11
# оръ 20
# орф 1
# луп 3
# унд 1
# орс 23
# ору 8
# орт 22
# исш 2
# исъ 21
# ися 1
# хдъ 1
# ист 177
# исц 1
# иси 146
# иск 382
# исл 26
# исм 9
# исн 1
# исо 15
# исп 12
# иса 26
# исб 1
# исв 1
# исд 1
# исе 2
# орн 25
# орм 56
# луч 46
# оро 20
# лус 1
# ори 131
# яхт 2
# оре 49
# орд 9
# орб 17
# ора 135
# орг 27
# орв 1
# dec 1
# вня 2
# орп 2
# туа 14
# агр 16
# bow 1
# bol 1
# хва 8
# отт 2
# имц 2
# иму 9
# имс 3
# абу 1
# огъ 4
# огр 44
# огс 1
# тън 3
# епт 3
# ерм 2
# пка 6
# аяс 2
# aya 1
# пки 4
# ибл 1
# сди 2
# азп 23
# мър 2
# мът 3
# мъх 1
# мъл 1
# азн 18
# мън 2
# ъща 14
# ert 1
# асп 8
# мъд 1
# мъж 9
# иба 6
# дхр 1
# нце 3
# оги 20
# огл 14
# огн 18
# ого 114
# ога 80
# flu 1
# cav 1
# cat 1
# жки 4
# ръх 1
# жка 2
# fle 1
# мпю 1
# гет 2
# гес 1
# гер 3
# фре 1
# зув 1
# фра 12
# псъ 1
# фро 1
# 231 1
# фри 5
# рги 24
# уба 4
# рго 27
# уще 1
# рга 27
# мев 1
# рге 2
# нъц 4
# все 53
# нът 7
# ебн 8
# зул 17
# нъж 5
# mar 1
# 142 1
# нък 4
# ьор 21
# mae 1
# зах 6
# дах 1
# ргу 4
# ргр 1
# зац 25
# man 5
# мел 3
# аах 1
# отк 18
# зар 52
# еба 7
# мен 303
# гед 1
# зат 40
# гео 1
# ген 15
# яна 14
# егу 9
# ълк 3
# яне 31
# узи 7
# яни 16
# уко 1
# дек 16
# вув 16
# arm 1
# sse 1
# лом 4
# лон 3
# лок 3
# лож 93
# лод 2
# лов 38
# лог 22
# tte 1
# анс 154
# тек 15
# тел 354
# теп 12
# тем 33
# тен 46
# тег 31
# ану 1
# теж 14
# тез 61
# 137 1
# gen 1
# рте 4
# сму 1
# еше 105
# сро 10
# рта 36
# щящ 1
# ртв 10
# ртн 26
# сра 7
# рто 3
# ешк 10
# рти 22
# еши 12
# сре 98
# аня 3
# сря 1
# рту 3
# сру 1
# ртъ 4
# ркт 2
# тещ 1
# анъ 13
# тет 27
# яше 1
# тер 65
# тес 7
# теч 3
# тех 17
# лоя 2
# всл 3
# лош 4
# лот 18
# лоу 4
# лор 1
# лос 3
# яну 2
# янс 1
# егв 2
# ега 38
# его 44
# егн 19
# егл 21
# вус 2
# вут 1
# еги 57
# лоп 1
# умъ 3
# умф 1
# лту 12
# чът 1
# адя 11
# адъ 32
# зше 1
# адч 9
# адх 1
# адс 3
# адр 1
# дви 32
# лав 14
# лаг 79
# лад 79
# лае 5
# инъ 4
# офа 1
# инф 30
# два 81
# инц 23
# лал 1
# лам 98
# инс 71
# инт 45
# ину 7
# лар 14
# лас 101
# ино 58
# лау 2
# ини 95
# лах 8
# инк 1
# лач 1
# инд 8
# ине 24
# инж 2
# ина 175
# инв 12
# лая 3
# адп 1
# адо 5
# адн 4
# адм 9
# адл 2
# ади 53
# адз 4
# адж 1
# аде 49
# дми 25
# адв 6
# адб 1
# ада 56
# умн 3
# зхо 19
# умп 1
# уми 8
# лср 1
# уме 61
# лта 26
# ума 14
# умб 1
# ъвк 2
# осв 28
# ъжк 2
# оса 22
# ито 226
# ити 140
# ъжн 4
# осе 10
# ите 1044
# осл 44
# оси 59
# ъжа 13
# осо 48
# осп 46
# бел 23
# осн 116
# пеш 11
# изч 3
# onr 1
# пет 17
# пес 3
# пер 25
# печ 8
# пец 13
# пех 6
# onu 1
# ian 1
# вся 8
# ютъ 1
# еих 1
# ias 1
# hue 1
# яхн 7
# ютн 5
# тте 2
# пел 3
# пек 11
# tta 1
# пеи 210
# пен 22
# pso 1
# вра 3
# ост 504
# осу 1
# оср 10
# унг 5
# вне 11
# осъ 38
# вни 108
# вно 45
# дпр 35
# иту 40
# and 2
# ane 1
# ang 3
# дст 77
# sac 1
# saa 1
# фиш 1
# шла 1
# ank 1
# рдя 3
# одб 2
# бса 1
# фиц 12
# sar 1
# одг 11
# sau 1
# оам 1
# одв 1
# фст 2
# оак 1
# оад 1
# бод 21
# бож 5
# боз 1
# фис 1
# бов 1
# бог 3
# бом 2
# бон 21
# mot 1
# боп 1
# шес 3
# бол 14
# 201 9
# 200 31
# 202 3
# бор 34
# азр 12
# бот 82
# тту 1
# азс 4
# нла 2
# фск 2
# рдо 2
# рди 12
# ъшн 2
# рде 8
# рда 4
# гск 1
# дхо 22
# дхв 1
# рис 36
# ике 1
# хно 10
# ъюз 87
# ика 159
# икв 4
# икн 8
# ико 77
# ики 31
# икл 8
# бач 32
# аба 11
# абв 1
# абд 2
# абе 6
# озе 3
# абз 1
# аби 16
# осс 1
# абл 18
# alk 1
# абн 2
# або 109
# ебе 4
# уле 10
# отъ 2
# шле 11
# отя 6
# ула 3
# ълъ 2
# лск 50
# отс 9
# отр 37
# отч 4
# ули 14
# отх 5
# ьом 1
# ият 387
# ьол 1
# yle 1
# вот 98
# вос 13
# вор 128
# вол 24
# вок 3
# вои 20
# воп 2
# пик 1
# вон 3
# вом 9
# вог 2
# вов 5
# воб 26
# иян 12
# воз 6
# зум 31
# вое 7
# вод 53
# отл 10
# ълн 58
# оти 36
# отп 9
# ото 331
# отн 170
# улт 34
# отг 44
# отв 57
# ълж 44
# ота 29
# ъла 1
# ълб 10
# оте 14
# отд 20
# абр 8
# абс 6
# щев 7
# абх 4
# mon 1
# ъкм 1
# икр 6
# ику 12
# икт 13
# икъ 2
# рпо 2
# rms 1
# жду 69
# рпи 1
# щеш 3
# рпе 4
# рпв 1
# дет 13
# рпа 1
# онц 3
# онч 5
# онф 14
# онт 25
# онс 22
# оня 5
# онъ 1
# деш 1
# път 38
# пър 34
# дещ 24
# пим 1
# пин 1
# люб 3
# пил 2
# пид 2
# пиз 1
# пиа 1
# пиш 1
# пих 2
# анг 17
# пир 8
# пис 16
# пит 31
# анн 16
# пък 1
# пъл 62
# онд 11
# оне 24
# онв 4
# онг 1
# она 64
# бал 21
# оно 91
# деф 4
# онн 22
# онк 29
# онл 2
# они 49
# жда 146
# жде 8
# дец 16
# жди 3
# ждн 2
# бам 1
# бан 8
# pos 1
# сьо 1
# риг 3
# kev 1
# nsk 1
# зку 3
# зкр 1
# рба 18
# мпр 3
# нол 6
# ном 70
# irk 1
# ноо 4
# ноп 3
# рби 3
# jol 1
# нов 191
# ног 66
# нод 23
# ное 2
# нож 3
# ноз 6
# вик 15
# вин 21
# дъл 64
# дък 8
# 500 2
# дър 123
# дът 15
# ихв 1
# вио 1
# ньо 20
# нош 66
# нощ 1
# мпа 2
# мпе 7
# нор 5
# нос 351
# нот 111
# мпо 2
# ноц 1
# зко 3
# вив 2
# зкл 19
# зки 6
# ихи 1
# зка 38
# физ 2
# виж 17
# eil 1
# ein 3
# зда 30
# еем 1
# здв 1
# вхо 1
# зде 8
# 257 1
# виш 8
# зди 1
# дси 1
# иср 1
# kho 1
# здн 2
# сащ 8
# лма 2
# дск 11
# уци 28
# щан 13
# сат 9
# сар 5
# сач 1
# уца 1
# сах 3
# ихт 4
# юда 7
# юде 6
# юдж 24
# ста 201
# ств 414
# сте 57
# люц 17
# люч 75
# стк 4
# лют 5
# стн 44
# сто 153
# люс 2
# стр 191
# стт 129
# сту 3
# люк 1
# вих 10
# стъ 66
# oia 1
# стя 4
# щно 36
# ъня 1
# сал 4
# саи 1
# сап 1
# сам 65
# сан 8
# саб 21
# сад 1
# здр 23
# зду 6
# еещ 1
# cch 2
# ееф 1
# здъ 3
# нех 1
# кач 13
# къп 2
# към 68
# укт 38
# укр 7
# къд 7
# укц 2
# къв 12
# бръ 5
# авч 2
# ъсн 6
# ъск 2
# авр 4
# авт 16
# авя 54
# ъсе 7
# ъсв 1
# ъса 1
# авъ 3
# илъ 1
# даж 2
# дае 10
# дад 28
# илю 2
# дав 45
# уши 5
# дан 120
# тци 2
# дал 26
# ушн 9
# даи 2
# дач 11
# дац 3
# или 124
# ило 20
# дат 201
# илн 39
# дая 4
# ила 63
# дащ 1
# иле 8
# аве 46
# авд 1
# ава 289
# бру 2
# авн 64
# аво 40
# ъст 17
# ави 214
# авл 28
# авк 6
# уки 1
# лрд 2
# къщ 2
# ука 3
# кът 3
# къс 11
# кър 3
# uru 1
# жур 1
# янд 4
# еут 1
# ирл 5
# ири 10
# иро 17
# ирн 7
# ирм 2
# зто 11
# ира 230
# впе 2
# ире 19
# хен 2
# хем 3
# оук 2
# оун 1
# оуп 4
# sen 1
# хез 2
# пля 1
# еря 2
# жик 1
# ябъ 1
# фат 2
# бра 47
# нои 4
# фаг 1
# ift 2
# ван 342
# фан 1
# фал 5
# фак 29
# 7х3 1
# оша 2
# acc 2
# пла 46
# пле 10
# ack 1
# пли 2
# хер 1
# пло 3
# бха 4
# бхв 5
# иря 10
# ноб 1
# зсл 18
# зтъ 2
# бхо 39
# шве 8
# cме 1
# шва 12
# рвя 1
# овл 4
# овк 6
# ови 108
# ово 166
# овн 55
# рящ 4
# ова 389
# рят 12
# ове 159
# овд 5
# бив 9
# жед 3
# биз 3
# бид 1
# бик 5
# бил 43
# жем 26
# жен 139
# био 3
# жел 22
# бим 2
# бин 3
# бит 34
# бир 35
# биц 5
# бич 2
# жер 9
# бих 37
# бия 2
# овъ 3
# рям 9
# рян 2
# овя 21
# ову 1
# овт 4
# овс 8
# ряв 31
# овц 1
# ряб 138
# рве 6
# рлс 1
# нно 45
# рва 13
# съж 26
# рвн 2
# lde 2
# рво 16
# рви 17
# рар 1
# ник 35
# oth 1
# рст 16
# нии 2
# ещя 1
# рся 2
# миз 2
# каш 1
# чаи 25
# uit 1
# чак 14
# чал 15
# кас 7
# кар 21
# мин 43
# кат 228
# ках 3
# мик 21
# чав 50
# кац 11
# гва 4
# цет 2
# рзи 1
# цер 1
# цес 20
# мер 77
# вто 31
# цед 9
# цев 1
# вти 3
# цем 1
# цен 50
# цел 59
# цеи 1
# вта 2
# ohn 1
# мич 49
# миц 15
# мих 2
# чая 4
# кан 36
# кам 48
# мис 161
# мир 28
# каб 1
# кав 7
# чар 2
# час 41
# каз 72
# каж 32
# ссе 1
# еща 27
# еще 13
# рсе 5
# цру 1
# рси 7
# ещи 15
# рск 11
# ещн 1
# рсо 2
# ещо 16
# all 1
# sch 1
# ali 1
# ald 2
# ale 2
# гур 57
# ala 1
# оже 142
# ожд 6
# фор 56
# ожа 5
# scu 1
# ожо 1
# ожн 57
# аят 13
# мпи 1
# ожи 34
# тищ 3
# ron 3
# тиш 1
# ott 1
# бвъ 6
# ктр 3
# фут 1
# фур 2
# юли 1
# тое 2
# бми 2
# бме 4
# бмя 1
# нфл 12
# юлм 2
# fav 2
# бва 140
# ржа 119
# фун 6
# рже 1
# ржд 1
# бви 4
# ржи 3
# ябв 138
# две 21
# фоб 1
# дче 24
# фон 13
# дчи 10
# аяв 6
# гум 4
# sma 1
# гул 9
# губ 10
# гуа 2
# гув 1
# аса 3
# tei 2
# асв 1
# 199 3
# асе 28
# ten 2
# ехъ 1
# аси 33
# аск 3
# асл 3
# асн 33
# асо 30
# рху 31
# tex 3
# тик 76
# шие 1
# шил 1
# гам 6
# ter 1
# шии 1
# яще 4
# tev 1
# ган 73
# тас 2
# тар 27
# гит 13
# тат 67
# тах 1
# гич 14
# гиш 1
# меш 1
# атв 10
# иля 5
# тая 14
# гия 26
# гжо 3
# abu 1
# учл 1
# гав 8
# гжа 2
# uda 1
# гад 1
# етк 6
# 132 1
# гае 1
# таб 10
# ршв 8
# гив 2
# тав 90
# тае 3
# гаж 17
# таз 57
# нем 13
# гии 18
# таи 14
# тал 20
# так 74
# тан 91
# там 42
# гио 22
# шит 27
# шис 2
# шир 19
# схе 3
# уро 1
# ших 2
# шиф 1
# шия 6
# ауч 12
# ехн 17
# ехм 1
# аст 138
# асу 41
# ехи 2
# тиж 1
# асъ 27
# нек 5
# рха 4
# еха 11
# ася 29
# vic 1
# lke 1
# vid 1
# яхм 12
# леч 6
# туц 27
# яха 22
# тур 38
# лет 18
# лес 24
# лер 2
# сли 5
# тус 2
# сло 30
# vit 1
# сла 13
# rkh 1
# сле 132
# нхе 1
# еос 1
# еот 5
# уше 4
# нха 1
# тут 1
# еан 1
# еак 3
# еал 14
# згл 24
# еаг 4
# зго 12
# згр 6
# ряк 2
# кча 3
# нъч 5
# еоб 43
# еог 1
# еод 3
# акч 1
# еоп 3
# сля 15
# уяз 5
# слу 67
# der 2
# нок 3
# тум 1
# тун 3
# лен 239
# лем 59
# лел 1
# лек 9
# тук 13
# леи 1
# туд 3
# леж 34
# ord 1
# лед 143
# лег 27
# лев 4
# тув 6
# туг 2
# азд 4
# азе 13
# азв 84
# азг 21
# аза 80
# азб 37
# азо 12
# иат 10
# азм 9
# иар 6
# азк 2
# азл 27
# ази 99
# убл 15
# хте 12
# дпи 3
# уби 6
# дпо 19
# ран 278
# убв 1
# дпа 3
# мра 4
# убе 12
# ащи 67
# att 1
# oyl 1
# хат 1
# хар 24
# офи 7
# хан 9
# ism 1
# хаи 2
# офо 1
# хаз 6
# вза 6
# мях 1
# офе 4
# хаг 2
# дко 4
# убя 2
# веш 3
# убс 4
# убр 1
# иал 58
# азх 13
# азу 32
# иан 9
# нуж 25
# азя 11
# азъ 1
# азш 10
# 007 3
# юст 2
# емс 1
# ger 1
# штъ 3
# дву 2
# ite 2
# юсю 2
# хор 38
# kfu 1
# тют 1
# yma 1
# ноа 1
# озр 6
# озу 2
# ксе 1
# бши 1
# юкс 1
# вии 1
# вил 37
# мам 29
# иха 15
# вим 22
# ъед 9
# пру 2
# ихм 11
# виг 1
# пря 11
# вие 48
# вид 46
# виз 5
# зно 16
# вищ 5
# пре 569
# пра 261
# вия 71
# evi 1
# вис 35
# вир 1
# про 397
# вит 145
# при 333
# вич 1
# озд 7
# сти 206
# оза 3
# озв 12
# озн 41
# озо 8
# ози 103
# озл 1
# хоа 1
# хов 8
# мад 1
# ход 86
# жов 2
# хож 1
# хол 5
# хоп 3
# юнх 1
# вещ 2
# рче 1
# ялн 2
# елт 4
# ним 34
# нин 3
# рзв 4
# рза 32
# рзо 8
# низ 36
# нид 5
# ние 423
# нив 6
# ниг 3
# ниа 1
# бля 1
# дре 4
# нту 3
# дра 25
# дро 4
# дрк 2
# дри 2
# атф 2
# атц 2
# атс 3
# атр 4
# ату 2
# атя 6
# люд 13
# атъ 19
# ате 208
# ата 617
# мом 18
# атн 13
# ато 181
# ати 100
# атл 2
# атк 4
# дби 6
# дру 62
# ash 1
# дръ 2
# ния 290
# лби 2
# нищ 21
# ниц 58
# нич 47
# мре 4
# зло 10
# нит 296
# нир 15
# нис 31
# лня 6
# зла 1
# учу 1
# вяш 1
# ося 1
# вяр 7
# зле 4
# вят 23
# звъ 27
# вях 1
# гле 43
# тбе 9
# ans 1
# гла 100
# тбо 1
# нфр 8
# гло 6
# гли 5
# рца 1
# скъ 2
# сфе 5
# рце 2
# сфа 1
# ефе 22
# скр 10
# рци 4
# ефи 11
# ску 7
# ефо 13
# клю 75
# toi 1
# нже 2
# сез 2
# кли 18
# лза 2
# кла 84
# ски 302
# уси 26
# мфа 1
# ско 92
# ска 214
# скв 40
# ске 5
# усо 2
# ste 3
# нфо 22
# глу 3
# уза 1
# лму 3
# aak 1
# нфе 2
# зве 13
# вям 5
# вян 20
# зва 94
# усв 1
# зво 29
# вяв 27
# вяе 2
# зви 48
# zym 1
# udi 1
# тсл 3
# ене 81
# енд 6
# енз 4
# енб 1
# ена 91
# енг 1
# енн 43
# ено 142
# ени 593
# енк 65
# дия 8
# тра 171
# тре 59
# диш 7
# уар 5
# диц 15
# lin 1
# диф 1
# дит 34
# lij 1
# тро 27
# ежа 14
# лдо 3
# аит 5
# аис 24
# аич 4
# аил 2
# аик 11
# аио 6
# аин 25
# аим 6
# аиг 2
# аив 2
# аиб 1
# лдс 1
# аие 2
# аид 3
# дип 3
# дио 3
# тру 82
# дим 53
# дил 2
# дик 3
# дии 6
# диз 15
# дие 6
# дид 5
# диг 10
# див 3
# лци 6
# диа 3
# енх 1
# ефт 1
# енц 26
# енс 19
# ент 217
# еня 8
# уни 14
# лне 17
# енъ 2
# скл 2
# учн 11
# кио 1
# уне 1
# rte 1
# руш 5
# орц 3
# .). 1
# чва 42
# рут 3
# ечт 3
# рус 14
# чви 1
# твя 11
# мки 15
# твъ 20
# rts 1
# мко 3
# мка 4
# уна 18
# тву 16
# твр 3
# явл 7
# яви 9
# уче 10
# яве 2
# ява 160
# збя 2
# ямс 1
# мот 11
# збр 6
# яма 49
# збо 11
# яме 11
# сеи 1
# зби 36
# цла 1
# збе 6
# aue 1
# ямо 18
# явя 4
# hio 1
# тво 183
# твл 2
# тбр 2
# тви 84
# тве 75
# тва 127
# рук 24
# ечк 6
# ечи 2
# руп 28
# рум 18
# счи 31
# рув 4
# руг 52
# руа 3
# еча 7
# руж 10
# руз 7
# ече 67
# руе 1
# кме 1
# arr 1
# set 1
# ses 1
# 310 1
# ass 1
# себ 3
# сег 34
# сев 6
# сед 120
# поу 4
# atu 1
# ari 1
# сел 35
# сек 37
# сен 28
# сем 19
# сеп 3
# сео 1
# нча 5
# нчи 1
# вме 15
# вял 1
# вре 50
# евн 6
# ево 13
# еви 13
# вро 273
# вру 3
# евр 288
# евт 3
# връ 33
# евъ 9
# сул 5
# imp 1
# авс 1
# сес 2
# сер 21
# сет 13
# сец 10
# сещ 2
# игр 12
# цис 1
# дго 11
# лга 3
# тхв 5
# гид 1
# лго 7
# лги 4
# бщя 1
# лур 1
# иор 18
# цар 1
# апя 1
# орк 2
# дна 71
# упа 20
# дне 38
# аел 8
# аед 12
# упи 9
# дно 64
# упо 6
# swi 2
# уша 4
# лъж 4
# лхи 1
# ушв 3
# луш 5
# чеш 3
# ъзр 5
# ъзс 13
# зяс 3
# оцъ 1
# хвъ 9
# зят 2
# хве 1
# ъзк 24
# ъзл 2
# ъзм 52
# ъзн 9
# ъзо 5
# ъзп 5
# nra 1
# ъзд 41
# зяв 11
# дап 1
# ляз 6
# 210 1
# упр 27
# упу 1
# илс 1
# fur 1
# аещ 1
# упц 2
# ski 1
# аец 1
# gem 1
# ает 17
# дня 1
# иод 6
# иоз 23
# агу 6
# иол 1
# иок 2
# ион 81
# иом 1
# иоп 1
# щат 45
# жия 2
# щас 1
# жищ 1
# цир 7
# жих 3
# gel 1
# жир 9
# фга 5
# жит 21
# rin 2
# vou 1
# ric 1
# ria 1
# обу 6
# обр 100
# обс 32
# обх 44
# объ 6
# обш 1
# общ 76
# обя 8
# илв 2
# бъл 4
# вка 12
# бъд 145
# иум 2
# вки 3
# вку 1
# бър 18
# пци 2
# обв 10
# 002 3
# оба 42
# 000 3
# обж 2
# 006 3
# 005 2
# обе 39
# обл 74
# оби 21
# pse 1
# обо 34
# обм 7
# обн 25
# ищн 1
# каи 2
# щав 3
# жим 21
# ppe 2
# щаб 3
# жил 5
# бно 23
# жие 1
# бна 4
# жиз 2
# дих 1
# щам 2
# жив 23
# tim 1
# мум 3
# нке 1
# нка 13
# уац 11
# фта 1
# нко 3
# дир 18
# нки 55
# как 109
# рем 62
# рен 74
# рео 6
# реп 94
# реи 4
# рек 52
# рел 4
# ред 483
# реж 19
# рез 93
# реа 22
# реб 29
# рев 27
# рег 75
# гри 11
# арт 55
# ..] 1
# арч 1
# ъср 6
# гро 6
# арф 2
# гра 142
# шен 128
# арш 1
# аря 33
# гре 8
# шел 1
# арг 3
# арв 1
# гръ 4
# чни 63
# шер 1
# чно 57
# аре 17
# ард 6
# арл 81
# арк 6
# гру 31
# аро 38
# нша 1
# арм 10
# рея 1
# реш 87
# рещ 37
# мли 6
# лде 2
# реф 15
# рех 5
# рец 4
# мле 3
# рер 7
# рес 54
# рет 40
# реу 1
# нкц 10
# нкр 22
# нкт 1
# нку 7
# ъоб 15
# ипп 1
# wis 1
# зам 9
# мес 57
# цип 21
# зап 37
# заи 9
# ции 72
# зак 57
# зал 14
# зад 40
# ебр 5
# циз 1
# япо 1
# всъ 14
# циа 58
# зав 21
# заг 14
# ijn 1
# тго 44
# сдр 1
# цие 3
# ршр 1
# еци 15
# ъци 8
# сци 1
# дур 8
# рфи 1
# еца 23
# ецб 1
# вее 2
# еце 4
# кни 3
# кно 5
# 300 1
# кна 2
# ецу 1
# рфу 2
# кне 1
# зте 2
# жоз 1
# zza 1
# нца 1
# жни 19
# нци 58
# дин 99
# еби 16
# ция 167
# зая 6
# мед 9
# защ 67
# меж 71
# мез 2
# меи 4
# циф 5
# мек 3
# зач 7
# мем 8
# зас 42
# вси 72
# цит 45
# впи 1
# кци 23
# kat 1
# кце 1
# епв 1
# епа 46
# епе 16
# епи 10
# nst 1
# епо 16
# дох 4
# дос 86
# дор 10
# дот 10
# уча 51
# тря 138
# лва 11
# тта 129
# ажб 1
# ажа 26
# аже 26
# ажд 58
# ажи 17
# кад 2
# ажн 56
# дич 3
# доб 87
# зти 1
# дог 40
# дов 63
# дон 8
# дом 8
# доп 23
# хум 5
# дои 2
# дол 6
# док 99
# епу 4
# 115 1
# епр 17
# dol 1
# пае 1
# епя 24
# 117 1
# uts 2
# cit 1
# ише 6
# ъдн 1
# оче 29
# вте 1
# оча 23
# ъди 8
# очв 10
# ифр 2
# ъде 107
# очн 28
# вля 11
# очи 15
# ъда 57
# очк 13
# ael 1
# охт 1
# мък 1
# лящ 1
# end 1
# nas 1
# gre 1
# ипа 6
# ипо 3
# gro 1
# ишл 12
# пал 11
# ипл 4
# ипи 6
# юро 2
# юри 3
# ипс 10
# ипъ 1
# tmu 1
# жня 5
# aga 1
# бщн 20
# вле 34
# бщо 9
# вла 3
# бщи 8
# очт 4
# ъдъ 6
# бще 22
# вло 4
# вли 15
# бща 11
# ифи 20
# кту 21
# дис 13
# ктъ 6
# 010 4
# ело 5
# елн 146
# 013 4
# ели 116
# еле 64
# елг 2
# елв 3
# ела 29
# ури 23
# lko 1
# урк 1
# лже 13
# урн 50
# лжа 13
# ура 23
# ург 5
# уре 11
# лжи 18
# дкр 69
# увр 4
# чув 5
# акъ 17
# esc 1
# яци 1
# акц 4
# акс 7
# акр 18
# аку 1
# акт 132
# ува 96
# ако 72
# аки 17
# акл 11
# уве 21
# аке 11
# дки 1
# чуж 1
# уво 1
# ака 76
# акв 51
# лши 1
# ъор 1
# uge 1
# уря 7
# лша 1
# урс 8
# урц 1
# вея 1
# еля 31
# [.. 1
# ene 2
# елх 1
# елф 1
# eve 1
# елс 104
# cas 1
# кте 6
# неш 5
# ктб 2
# кта 22
# кто 90
# ктн 3
# кти 106
# rro 1
# uel 1
# дув 1
# зът 2
# uer 1
# яху 1
# ига 22
# иге 4
# иги 8
# иго 1
# игн 33
# ъчи 2
# ъчк 2
# бур 4
# ъчн 16
# фао 1
# rac 1
# ъчв 1
# ъче 4
# lec 1
# lee 1
# ерп 3
# ръп 1
# len 1
# игу 57
# ler 1
# чер 34
# лст 70
# rde 1
# зъм 19
# чта 3
# воя 8
# оек 16
# cad 1
# чещ 2
# чти 4
# wif 2
# ръж 4
# буж 1
# буд 2
# ръб 2
# гиб 1
# рле 4
# ахо 1
# век 22
# вел 19
# веи 1
# wit 1
# вео 3
# ръг 1
# душ 14
# вен 152
# дух 5
# веж 18
# вед 54
# дус 3
# жно 86
# соф 1
# ощи 8
# щях 2
# che 1
# usa 1
# ощн 2
# chi 2
# жне 1
# нво 1
# жна 15
# още 30
# оот 1
# pfl 1
# ркм 1
# рко 2
# рки 37
# нве 14
# ощт 2
# ощр 4
# бжа 2
# рка 7
# ркв 1
# ъот 18
# дум 14
# дун 18
# дук 16
# ndo 1
# дуи 2
# вет 144
# нва 6
# вер 45
# вес 25
# вец 2
# веч 60
# дуа 1
# три 35
# пна 3
# буч 6
# буц 1
# пни 5
# пно 3
# ахм 11
# чих 3
# чиц 3
# ахи 2
# чис 9
# чит 83
# ахе 1
# чия 6
# аха 25
# ахв 3
# нгр 1
# ибу 1
# есъ 7
# eвр 1
# еся 1
# есу 8
# ест 217
# мул 11
# тмя 1
# мун 6
# иша 9
# пяв 1
# пян 1
# пям 12
# ржо 1
# оид 2
# оиз 29
# увс 3
# оин 21
# оил 1
# оик 2
# оич 10
# оис 6
# оит 219
# пях 6
# пят 7
# тме 3
# гма 1
# еси 20
# есл 3
# еск 117
# есн 19
# есп 7
# есо 8
# еса 17
# есв 3
# есе 29
# мущ 1
# чие 3
# чив 12
# чим 11
# чин 56
# нге 1
# чии 1
# чик 8
# нга 23
# чез 1
# спе 43
# яст 7
# спа 25
# спо 130
# спл 2
# спи 9
# нса 5
# жва 3
# нсе 5
# jne 1
# нси 23
# тят 12
# нск 58
# нсн 1
# тях 17
# нсп 19
# нсо 41
# въз 105
# tso 1
# въд 1
# въг 2
# във 54
# екъ 3
# въп 95
# вън 16
# екч 2
# екр 8
# екс 20
# ект 93
# еку 1
# зпо 40
# зпи 4
# зпл 4
# яко 46
# рът 11
# зпа 1
# гин 2
# dad 1
# eme 1
# dab 1
# зпъ 24
# dal 1
# якъ 1
# зпр 23
# dat 1
# мвр 6
# еко 15
# daw 1
# еки 26
# 020 3
# въс 1
# вър 141
# еке 4
# екз 1
# ека 28
# екв 6
# нсу 8
# нст 101
# нсф 1
# тяв 8
# ълв 4
# нсь 1
# еят 3
# ясе 2
# sim 1
# юго 1
# спр 29
# спя 6
# ясн 38
# фищ 1
# алт 10
# алу 1
# алс 6
# алц 6
# дла 11
# дло 52
# ълг 15
# уел 2
# аля 15
# дли 9
# ъфт 1
# иду 1
# идр 1
# идя 3
# our 1
# идъ 1
# ечл 2
# reu 1
# reh 1
# ren 1
# кув 17
# кум 15
# куп 2
# кул 13
# куц 1
# куч 1
# кур 10
# кус 6
# бьо 1
# eck 1
# 149 1
# сче 2
# идж 1
# иде 33
# руб 2
# her 1
# ида 16
# идо 7
# идн 10
# иди 15
# алв 2
# ала 42
# алб 4
# руд 44
# алд 3
# але 39
# алк 26
# али 110
# ало 24
# алм 4
# алн 127
# рях 1
# ехр 2
# art 1
# ряс 1
# дсм 1
# пва 5
# ъпр 99
# них 1
# пящ 1
# ъпъ 1
# ъбн 1
# ъбл 1
# ъби 4
# 025 1
# ъбе 1
# ъба 1
# кмо 1
# чем 1
# ъпа 6
# hel 1
# ъпв 3
# lil 1
# ъпе 1
# ъпи 4
# ъпк 10
# ъпл 6
# ъпн 11
# ben 1
# lim 1
# яга 9
# жае 4
# рла 88
# ягв 2
# бед 27
# без 57
# жав 134
# жан 9
# мпс 1
# рли 1
# бек 9
# бен 19
# жаи 1
# жал 17
# фла 1
# щин 1
# пют 1
# жет 32
# 338 1
# фли 12
# sel 1
# mil 1
# нго 1
# arl 1
# mic 2
# жес 14
# nuc 1
# бии 1
# sol 1
# шно 18
# co2 1
# шни 32
# awi 1
# лти 3
# шна 10
# cke 1
# щия 15
# риц 3
# щит 60
# ахр 1
# 023 1
# urt 1
# бер 10
# бет 1
# жас 2
# ахт 5
# жат 13
# бещ 4
# беш 57
# bia 1
# чил 6
# жащ 2
# рля 5
# охо 2
# ond 1
# ъвт 1
# ъвс 12
# чре 16
# охе 2
# ъвъ 3
# оха 3
# лие 10
# бях 25
# цки 2
# бят 2
# бяс 5
# ряд 3
# nge 2
# еве 15
# ngl 1
# егр 9
# ряг 1
# ngu 1
# ъще 35
# ибн 4
# ибо 3
# ъщо 67
# ева 5
# ъщн 15
# ибе 7
# ъщи 8
# удс 1
# 995 1
# ибъ 1
# цка 1
# ибр 2
# ибс 1
# лмс 1
# 999 1
# янн 6
# ври 6
# уал 8
# нни 36
# вск 8
# бяг 2
# бяв 4
# тящ 2
# бял 1
# ъвз 1
# ици 119
# ъве 73
# ица 37
# ъвм 8
# зши 10
# shm 1
# охр 1
# aen 1
# пун 1
# лъг 1
# пуб 15
# пув 1
# нна 12
# фия 2
# оди 115
# одл 5
# одк 73
# одн 46
# взе 22
# одп 13
# одо 35
# фич 3
# ода 85
# уан 2
# иши 3
# оде 20
# одд 4
# ишн 5
# фир 3
# лез 13
# рия 50
# хна 3
# бат 18
# рит 106
# бар 11
# рир 29
# рич 33
# хни 11
# рих 3
# щря 4
# щен 10
# щем 4
# lug 1
# олд 4
# лоб 6
# юци 17
# ken 1
# eul 1
# щес 44
# щна 1
# щет 9
# рил 41
# рик 31
# баи 2
# рии 13
# рип 2
# рио 39
# рин 43
# рим 38
# бав 16
# рив 22
# риб 14
# риа 9
# риз 62
# риж 6
# рие 66
# рид 8
# взр 1
# дсе 91
# фин 58
# одъ 33
# фик 28
# одя 9
# одс 12
# одр 4
# оду 24
# jia 1
# одх 23
# одч 25
# одц 1
# пуш 1
# пус 12
# пут 1
# екц 7
# аук 1
# неф 3
# неч 1
# нец 1
# нес 51
# нер 41
# неу 3
# нет 197
# нея 5
# цър 1
# нещ 16
# ещу 17
# ауд 1
# цъф 1
# еуч 2
# шка 5
# еус 1
# жци 1
# шко 1
# шки 4
# мсп 4
# тоя 47
# мск 3
# тоу 1
# тот 3
# тос 8
# тор 81
# точ 33
# впо 1
# окв 2
# ока 48
# оке 1
# окл 70
# оки 17
# око 51
# оку 20
# окт 1
# окс 1
# окр 37
# еша 17
# окх 5
# окъ 2
# lge 1
# тол 9
# ток 31
# тои 45
# топ 33
# тоо 1
# тон 7
# том 9
# тог 9
# тов 263
# тоз 81
# hma 1
# мст 4
# тод 10
# ешн 28
# рча 21
# чан 3
# рчи 3
# щят 1
# чов 25
# нед 18
# нез 30
# неж 3
# неб 5
# нег 26
# нев 18
# нен 102
# миг 5
# неп 21
# нео 45
# неи 11
# нел 4
# тдр 1
# кис 3
# кир 5
# кит 119
# кия 142
# усъ 3
# avo 1
# тст 32
# avi 1
# уст 31
# лян 9
# ili 1
# тсъ 1
# ava 2
# емъ 4
# нум 1
# нул 1
# емя 3
# емт 1
# мил 14
# нуе 1
# нуд 6
# нуа 2
# ман 42
# зни 19
# мал 54
# мак 18
# маи 11
# зна 105
# маг 10
# мав 2
# зне 10
# 011 1
# мащ 4
# маш 6
# мач 2
# мац 19
# мах 5
# маф 2
# мат 92
# мас 8
# мар 10
# емл 6
# еми 63
# рши 7
# емо 35
# емп 1
# емн 4
# емв 5
# съм 28
# ема 74
# емб 1
# бук 1
# нут 1
# еме 85
# усл 29
# уск 8
# лзв 29
# усп 21
# етв 9
# усн 6
# усм 2
# лзи 2
# уса 1
# тск 2
# dav 1
# усе 1
# лзо 1
# киб 2
# кив 9
# юна 1
# етн 51
# щта 2
# 021 1
# con 1
# кин 5
# ето 478
# вът 12
# ивя 1
# рша 1
# ивш 5
# ети 64
# екл 9
# хро 1
# уго 4
# уги 43
# хри 5
# етл 2
# уга 13
# хра 14
# weg 1
# 399 1
# wei 1
# сир 21
# ичл 1
# ade 1
# ada 1
# кхо 5
# adi 1
# гви 1
# аем 38
# зну 1
# аен 2
# ивн 44
# ъцк 3
# иво 40
# иви 15
# ивл 3
# ивк 1
# иве 29
# ива 62
# ъце 1
# тад 1
# 986 1
# ючъ 1
# пад 11
# дни 74
# ншн 6
# паз 67
# упя 1
# пав 1
# пан 46
# отм 4
# риу 1
# пак 20
# лио 10
# бюд 24
# est 2
# ечу 1
# вдр 1
# ляд 4
# оет 74
# еяс 1
# оес 2
# ичп 1
# цуе 1
# ичн 86
# ичк 72
# чуд 3
# ичи 46
# сил 54
# иче 162
# сии 9
# ича 16
# ъгл 39
# 0те 1
# dcm 1
# чух 3
# пти 6
# ичу 1
# чуя 2
# сип 2
# ища 6
# оем 4
# оен 5
# бюр 2
# ище 21
# вдо 1
# оев 3
# вди 7
# ищо 6
# оше 66
# пац 6
# пар 122
# пас 23
# пат 19
# nda 1
# пая 1
# nde 2
# оши 3
# хме 38
# юче 16
# отб 11
# бас 1
# ючв 25
# ючо 3
# ючи 30
# 70т 1
# kre 1
# олс 7
# олу 12
# owi 1
# етт 1
# олш 1
# щър 1
# олъ 1
# олю 23
# оля 50
# дле 3
# звл 2
# иел 1
# бза 1
# етя 3
# van 2
# уеб 1
# ечн 1
# яка 10
# алъ 5
# съц 1
# афт 1
# афс 4
# афр 4
# тде 15
# афи 14
# bur 1
# афг 5
# кал 41
# афа 1
# bui 1
# мте 1
# ola 1
# чаш 1
# eas 1
# тда 5
# кап 3
# аеш 1
# ezz 1
# бах 1
# ола 22
# мия 8
# lva 1
# оле 53
# олз 34
# оли 112
# олк 39
# олм 5
# олн 16
# оло 50
# ари 39
# змя 2
# змр 1
# гну 1
# трь 1
# оце 41
# мбу 3
# чат 19
# нтъ 21
# ink 1
# ine 3
# гне 28
# миш 11
# нтр 21
# нтс 1
# гна 42
# етд 1
# ете 74
# сък 2
# съл 9
# ета 76
# сън 2
# съо 34
# съп 4
# съб 6
# съв 83
# съг 36
# съд 29
# съе 9
# рше 9
# съз 33
# сит 37
# нди 16
# сис 21
# ндо 4
# сич 73
# сих 1
# нда 22
# сия 132
# нде 9
# сиг 60
# сиа 2
# сиз 1
# сид 5
# сие 8
# сик 3
# нду 7
# ндр 1
# ндс 2
# сио 4
# лук 1
# сим 23
# син 5
# същ 125
# етр 3
# етс 21
# съю 87
# сър 31
# със 61
# сът 33
# оци 29
# етъ 22
# съч 3
# нтн 7
# нто 4
# нти 78
# тпр 7
# нте 53
# тпу 2
# нта 73
# нтв 1
# зми 5
# яла 6
# зуч 1
# мби 6
# змо 50
# зма 10
# рсп 3
# мба 3
# зме 36
# яло 18

# %% [markdown]
# ## Отбор признаков
#
# Здесь предстоит выбрать топовые n-граммы для каждого языка (`select_features`) и отфильтровать документы так, чтобы в них остались только отобранные (`keep_only_features`)

# %%
from collections import Counter
def select_features(lang_freq, top_tokens):
    """
    From each language selects top_tokens to be used as features
    
    TODO: Implement this — DONE

    Returns:
        set(unicode tokens)
    """
    features = set()
    for lang, (lid, token_freq) in lang_freq.items():
        c = Counter(token_freq)
        top = c.most_common(top_tokens)
        features.update(t[0] for t in top)
    return features

print select_features({'bg':(0, {'a':2, 'b':1})}, 1)
# Out:
# set(['a'])

# %%
def keep_only_features(docs, features):
    """
    Removes non-feature tokens from the document representations
    """
    for token_freq in docs:
        for token in list(token_freq.keys()):
            if token not in features:
                del token_freq[token]

# %%
# Select top n features for each lang
features = select_features(lang_freq, TOP_TOKENS)
# Remove from documents all features except the selected
keep_only_features(docs, features)

# Transform documents to numpy matrix
dv = DictVectorizer()  # комм.: запомнить, классная вещь
# CountVectorizer еще круче. Начни уже носить с собой тетрадь!
x = dv.fit_transform(docs).todense()
y = numpy.array(langs)
print("Data set shape x=(%d x %d) y=%d" % (x.shape[0], x.shape[1], len(y)))
# Out:
# Data set shape x=(21000 x 151) y=21000

# %% [markdown]
# ## Создание и настройка модели
#
# В этом пункте требуется реализовать модель (NB) и оценить метрику `accuracy` на кросс-валидации.

# %%
from sklearn.base import BaseEstimator, ClusterMixin
import numpy as np


class MNB(BaseEstimator, ClusterMixin): 
    
    def __init__(self):
        """
        Инициализация метода
        """
        pass

    def fit(self, X, y=None):
        """
        Процедура обучения
        """
        
        ## Your Code Here
        # ...
        
        return self

    def predict_proba(self, X, y=None):
        """
        Процедура предсказания вероятности класса
        
        """
        return np.random.rand(X.shape[0], 1).reshape(-1, 1)
    
    def predict(self, X, y=None):
        """
        Процедура предсказания класса
        
        """
        return np.random.rand(X.shape[0], 1).reshape(-1, 1)
    

def create_model():
    """
    Initialise an NB model, supported by Sklearn

    Returns:
        Sklearn model instance
    """
    return MNB()

# %%
from sklearn.model_selection import cross_val_score
# from sklearn.naive_bayes import MultinomialNB
def validate_model(model, x, y, folds=10):
    """
    Computes cross-validation score for the given data set and model.
    
    TODO: Implement this

    Returns:
        A numpy.array of accuracy scores.
    """
    
    return cross_val_score(model, x, y, cv=folds);

# %%
def plot_roc(model, x, y, class_ind=0):    
    # Compute ROC curve
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.5, random_state=0)
    fit = model.fit(x_train, y_train)
    y_prob = fit.predict_proba(x_test)   
    fpr, tpr, _ = roc_curve(y_test, y_prob[:, class_ind], pos_label=class_ind)
    roc_auc = auc(fpr, tpr)
    # Plot ROC curve
    plt.fill_between(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc, alpha=0.3)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic for class index %s' % class_ind)

# %% [markdown]
# _Замечание_ : обратите внимание, что тут нужно реализовать перебор параметров.

# %%
# TODO: Implement parameter grid search here
model = create_model()
# Print cross-validated accturacy
scores = validate_model(model, x, y)
print("Model mean accuracy: {}".format(numpy.mean(scores)))

# Plot ROC
plt.figure(figsize=(8, 8))
plot_roc(model, x, y, 0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-897cd3287e3e> in <module>()
#       2 model = create_model()
#       3 # Print cross-validated accturacy
# ----> 4 scores = validate_model(model, x, y)
#       5 print("Model mean accuracy: {}".format(numpy.mean(scores)))
#       6
#
# <ipython-input-13-9d3562f4a19b> in validate_model(model, x, y, folds)
#      11     """
#      12
# ---> 13     cross_val_score(model, x, y, folds);
#      14     return [0.9, 0.9, 0.8]
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     333     """
#     334     # To ensure multimetric format is not supported
# --> 335     scorer = check_scoring(estimator, scoring=scoring)
#     336
#     337     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/metrics/scorer.pyc in check_scoring(estimator, scoring, allow_none)
#     297                 "If no scoring is specified, the estimator passed should "
#     298                 "have a 'score' method. The estimator %r does not."
# --> 299                 % estimator)
#     300     else:
#     301         raise ValueError("scoring value should either be a callable, string or"
#
# TypeError: If no scoring is specified, the estimator passed should have a 'score' method. The estimator MNB() does not.

# %% [markdown]
# ## Создание и настройка модели
#
# В этом пункте требуется реализовать модель (NB) и перебрать различные значения параметров. Предлагается попробовать Multinumial и Bernoulli варианты из sklearn и несколько значений параметров (alpha, binarize, fit_prior) и выбрать наилучшую модель на основании метрики `accuracy`, полученной на кросс-валидации.

# %%
def create_model():
    """
    Initialise an NB model, supported by Sklearn

    Returns:
        Sklearn model instance
    """
    return MultinomialNB()

# %%
model = create_model()
# Print cross-validated accturacy
scores = validate_model(model, x, y)
print("Model mean accuracy: {}".format(numpy.mean(scores)))

# Plot ROC
plt.figure(figsize=(10, 10))
plot_roc(model, x, y, 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-88099a385b3e> in <module>()
#       1 model = create_model()
#       2 # Print cross-validated accturacy
# ----> 3 scores = validate_model(model, x, y)
#       4 print("Model mean accuracy: {}".format(numpy.mean(scores)))
#       5
#
# <ipython-input-13-9d3562f4a19b> in validate_model(model, x, y, folds)
#      11     """
#      12
# ---> 13     cross_val_score(model, x, y, folds);
#      14     return [0.9, 0.9, 0.8]
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_validation.pyc in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     190
#     191     """
# --> 192     X, y, groups = indexable(X, y, groups)
#     193
#     194     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# /Users/Alexander/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _num_samples(x)
#     117         if len(x.shape) == 0:
#     118             raise TypeError("Singleton array %r cannot be considered"
# --> 119                             " a valid collection." % x)
#     120         return x.shape[0]
#     121     else:
#
# TypeError: Singleton array array(10) cannot be considered a valid collection.

# %% [markdown]
# ## Дополнительно
#
# - Выясните, какие классы чаще всего путаются (на кросс-валидации!)
# - Сравните NB и KNN
