# %% [markdown]
# # Как быстро посчитать расстояние между парами объектов
#
# $ X $ - n x d матрица
#
# $ Y $ - m x d матрица
#
# Необходимо найти матрицу $D$, такую что $D[i, j]$ - это расстояние между $i-ой$ строкой матрицы $X$ и $j-ой$ строкой матрицы $Y$
#
# $D$ - n x m матрица
#
# $ D[i, j] = dist(X[i, :], Y[j, :]) $ $ \forall i, j$
#
# В качестве расстояния возьмем евклидово.
#
# Пусть $x$ - строка матрицы X, а $y$ - строка матрицы Y, тогда
#
# $dist(x, y) = \sqrt{\sum_{i=0}^d (x_i - y_i)^2}$

# %%
import pandas as pd
import numpy as np
from line_profiler import LineProfiler
from sklearn import datasets

# %load_ext Cython

# %%
def profile_print(func_to_call, *args):
    profiler = LineProfiler()
    profiler.add_function(func_to_call)
    profiler.runcall(func_to_call, *args)
    profiler.print_stats()

# %%
num_features = 100

# we will need only feature representations
X = datasets.make_blobs(777, n_features=num_features, centers=10)[0]
Y = datasets.make_blobs(500, n_features=num_features, centers=30)[0]
X.shape, Y.shape
# Out:
# ((777, 100), (500, 100))

# %% [markdown]
# ### Naive way

# %%
def vector_distance(x, y):
    dist = ((x - y) ** 2).sum()
    return np.sqrt(dist)


def naive_mdist(X, Y):
    D = np.zeros((X.shape[0], Y.shape[0]))
    for i, x in enumerate(X):
        for j, y in enumerate(Y):
            D[i, j] = vector_distance(x, y)
    return D

# %%
# %%timeit
naive_mdist(X, Y)
# Out:
# 1.44 s ± 55.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
profile_print(naive_mdist, X, Y)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 1.88971 s
# File: <ipython-input-4-1f07dfd582d9>
# Function: naive_mdist at line 6
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      6                                           def naive_mdist(X, Y):
#      7         1        498.0    498.0      0.0      D = np.zeros((X.shape[0], Y.shape[0]))
#      8       778        339.0      0.4      0.0      for i, x in enumerate(X):
#      9    389277     176091.0      0.5      9.3          for j, y in enumerate(Y):
#     10    388500    1712778.0      4.4     90.6              D[i, j] = vector_distance(x, y)
#     11         1          0.0      0.0      0.0      return D

# %%
D_naive = naive_mdist(X, Y)

# %% [markdown]
# ## Better numpy

# %% [markdown]
# ### How to write euclidean distance in vector-matrix form ?
#
# #### Broadcasting
# http://scipy.github.io/old-wiki/pages/EricsBroadcastingDoc

# %%
broad = X - Y[0]
not_broad = np.array([x - Y[0] for x in X])

print('Shapes:', broad.shape, not_broad.shape)
print('Number of different values:', (broad != not_broad).sum())
# Out:
# Shapes: (777, 100) (777, 100)
# Number of different values: 0

# %%
# %%timeit 
X - Y[0]
# Out:
# 53.9 µs ± 181 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
np.array([x - Y[0] for x in X])
# Out:
# 701 µs ± 5.41 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def broadcast_numpy_dist(X, Y):
    D = np.zeros((X.shape[0], Y.shape[0]))
    for j, y in enumerate(Y):
        dist = ((X - y) ** 2).sum(axis=1)
        D[:, j] = np.sqrt(dist)
    return D

# %%
D_broadcast = broadcast_numpy_dist(X, Y)
np.abs(D_broadcast - D_naive).sum()
# Out:
# 0.0

# %%
# %%timeit 
broadcast_numpy_dist(X, Y)
# Out:
# 60.7 ms ± 791 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
profile_print(broadcast_numpy_dist, X, Y)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.065495 s
# File: <ipython-input-17-509813464366>
# Function: broadcast_numpy_dist at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def broadcast_numpy_dist(X, Y):
#      2         1        328.0    328.0      0.5      D = np.zeros((X.shape[0], Y.shape[0]))
#      3       501        370.0      0.7      0.6      for j, y in enumerate(Y):
#      4       500      60403.0    120.8     92.2          dist = ((X - y) ** 2).sum(axis=1)
#      5       500       4394.0      8.8      6.7          D[:, j] = np.sqrt(dist)
#      6         1          0.0      0.0      0.0      return D

# %% [markdown]
# ### Pure numpy

# %% [markdown]
# $x$, $y$ - одномерные вектора
# $$ dist(x, y)^2 = \sum_i(x_i - y_i)^2 = \sum_i(x_i^2 - 2x_i y_i + y_i^2) = \sum_ix_i^2 -2 \sum_ix_i y_i + \sum_iy_i^2$$
#
# $$ numpy :  np.sum(x \cdot \cdot 2 - 2 \cdot x \cdot y - y \cdot \cdot 2) $$

# %%
def numpy_dist(X, Y):
    x_dist = (X ** 2).sum(axis=1)
    y_dist = (Y ** 2).sum(axis=1)
    xy_dist = X.dot(Y.T)
    dist = - 2 * xy_dist + y_dist + x_dist.reshape(-1, 1)
    return np.sqrt(dist)

# %%
D_numpy = numpy_dist(X, Y)
np.abs(D_numpy - D_naive).sum()
# Out:
# 1.7290346931986278e-09

# %%
# %%timeit 
numpy_dist(X, Y)
# Out:
# 2.65 ms ± 24.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
profile_print(numpy_dist, X, Y)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.005641 s
# File: <ipython-input-22-5ad2b5bec2ce>
# Function: numpy_dist at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def numpy_dist(X, Y):
#      2         1        280.0    280.0      5.0      x_dist = (X ** 2).sum(axis=1)
#      3         1        268.0    268.0      4.8      y_dist = (Y ** 2).sum(axis=1)
#      4         1       1663.0   1663.0     29.5      xy_dist = X.dot(Y.T)
#      5         1       2037.0   2037.0     36.1      dist = - 2 * xy_dist + y_dist + x_dist.reshape(-1, 1)
#      6         1       1393.0   1393.0     24.7      return np.sqrt(dist)

# %% [markdown]
# ### Library (maybe the best way)

# %%
from scipy.spatial.distance import cdist

# %%
D_scipy = cdist(X, Y, metric='euclidean')
np.abs(D_scipy - D_naive).sum()
# Out:
# 2.2618706907451269e-09

# %%
# %%timeit 
cdist(X, Y, metric='euclidean')
# Out:
# 12.4 ms ± 204 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
profile_print(cdist, X, Y)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.014456 s
# File: /home/dmitry/anaconda3/lib/python3.6/site-packages/scipy/spatial/distance.py
# Function: cdist at line 1838
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1838                                           def cdist(XA, XB, metric='euclidean', p=None, V=None, VI=None, w=None):
#   1839                                               """
#   1840                                               Computes distance between each pair of the two collections of inputs.
#   1841
#   1842                                               See Notes for common calling conventions.
#   1843
#   1844                                               Parameters
#   1845                                               ----------
#   1846                                               XA : ndarray
#   1847                                                   An :math:`m_A` by :math:`n` array of :math:`m_A`
#   1848                                                   original observations in an :math:`n`-dimensional space.
#   1849                                                   Inputs are converted to float type.
#   1850                                               XB : ndarray
#   1851                                                   An :math:`m_B` by :math:`n` array of :math:`m_B`
#   1852                                                   original observations in an :math:`n`-dimensional space.
#   1853                                                   Inputs are converted to float type.
#   1854                                               metric : str or callable, optional
#   1855                                                   The distance metric to use.  If a string, the distance function can be
#   1856                                                   'braycurtis', 'canberra', 'chebyshev', 'cityblock', 'correlation',
#   1857                                                   'cosine', 'dice', 'euclidean', 'hamming', 'jaccard', 'kulsinski',
#   1858                                                   'mahalanobis', 'matching', 'minkowski', 'rogerstanimoto', 'russellrao',
#   1859                                                   'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean',
#   1860                                                   'wminkowski', 'yule'.
#   1861                                               p : double, optional
#   1862                                                   The p-norm to apply
#   1863                                                   Only for Minkowski, weighted and unweighted. Default: 2.
#   1864                                               w : ndarray, optional
#   1865                                                   The weight vector.
#   1866                                                   Only for weighted Minkowski. Mandatory
#   1867                                               V : ndarray, optional
#   1868                                                   The variance vector
#   1869                                                   Only for standardized Euclidean. Default: var(vstack([XA, XB]), axis=0, ddof=1)
#   1870                                               VI : ndarray, optional
#   1871                                                   The inverse of the covariance matrix
#   1872                                                   Only for Mahalanobis. Default: inv(cov(vstack([XA, XB]).T)).T
#   1873
#   1874                                               Returns
#   1875                                               -------
#   1876                                               Y : ndarray
#   1877                                                   A :math:`m_A` by :math:`m_B` distance matrix is returned.
#   1878                                                   For each :math:`i` and :math:`j`, the metric
#   1879                                                   ``dist(u=XA[i], v=XB[j])`` is computed and stored in the
#   1880                                                   :math:`ij` th entry.
#   1881
#   1882                                               Raises
#   1883                                               ------
#   1884                                               ValueError
#   1885                                                   An exception is thrown if `XA` and `XB` do not have
#   1886                                                   the same number of columns.
#   1887
#   1888                                               Notes
#   1889                                               -----
#   1890                                               The following are common calling conventions:
#   1891
#   1892                                               1. ``Y = cdist(XA, XB, 'euclidean')``
#   1893
#   1894                                                  Computes the distance between :math:`m` points using
#   1895                                                  Euclidean distance (2-norm) as the distance metric between the
#   1896                                                  points. The points are arranged as :math:`m`
#   1897                                                  :math:`n`-dimensional row vectors in the matrix X.
#   1898
#   1899                                               2. ``Y = cdist(XA, XB, 'minkowski', p)``
#   1900
#   1901                                                  Computes the distances using the Minkowski distance
#   1902                                                  :math:`||u-v||_p` (:math:`p`-norm) where :math:`p \\geq 1`.
#   1903
#   1904                                               3. ``Y = cdist(XA, XB, 'cityblock')``
#   1905
#   1906                                                  Computes the city block or Manhattan distance between the
#   1907                                                  points.
#   1908
#   1909                                               4. ``Y = cdist(XA, XB, 'seuclidean', V=None)``
#   1910
#   1911                                                  Computes the standardized Euclidean distance. The standardized
#   1912                                                  Euclidean distance between two n-vectors ``u`` and ``v`` is
#   1913
#   1914                                                  .. math::
#   1915
#   1916                                                     \\sqrt{\\sum {(u_i-v_i)^2 / V[x_i]}}.
#   1917
#   1918                                                  V is the variance vector; V[i] is the variance computed over all
#   1919                                                  the i'th components of the points. If not passed, it is
#   1920                                                  automatically computed.
#   1921
#   1922                                               5. ``Y = cdist(XA, XB, 'sqeuclidean')``
#   1923
#   1924                                                  Computes the squared Euclidean distance :math:`||u-v||_2^2` between
#   1925                                                  the vectors.
#   1926
#   1927                                               6. ``Y = cdist(XA, XB, 'cosine')``
#   1928
#   1929                                                  Computes the cosine distance between vectors u and v,
#   1930
#   1931                                                  .. math::
#   1932
#   1933                                                     1 - \\frac{u \\cdot v}
#   1934                                                              {{||u||}_2 {||v||}_2}
#   1935
#   1936                                                  where :math:`||*||_2` is the 2-norm of its argument ``*``, and
#   1937                                                  :math:`u \\cdot v` is the dot product of :math:`u` and :math:`v`.
#   1938
#   1939                                               7. ``Y = cdist(XA, XB, 'correlation')``
#   1940
#   1941                                                  Computes the correlation distance between vectors u and v. This is
#   1942
#   1943                                                  .. math::
#   1944
#   1945                                                     1 - \\frac{(u - \\bar{u}) \\cdot (v - \\bar{v})}
#   1946                                                              {{||(u - \\bar{u})||}_2 {||(v - \\bar{v})||}_2}
#   1947
#   1948                                                  where :math:`\\bar{v}` is the mean of the elements of vector v,
#   1949                                                  and :math:`x \\cdot y` is the dot product of :math:`x` and :math:`y`.
#   1950
#   1951
#   1952                                               8. ``Y = cdist(XA, XB, 'hamming')``
#   1953
#   1954                                                  Computes the normalized Hamming distance, or the proportion of
#   1955                                                  those vector elements between two n-vectors ``u`` and ``v``
#   1956                                                  which disagree. To save memory, the matrix ``X`` can be of type
#   1957                                                  boolean.
#   1958
#   1959                                               9. ``Y = cdist(XA, XB, 'jaccard')``
#   1960
#   1961                                                  Computes the Jaccard distance between the points. Given two
#   1962                                                  vectors, ``u`` and ``v``, the Jaccard distance is the
#   1963                                                  proportion of those elements ``u[i]`` and ``v[i]`` that
#   1964                                                  disagree where at least one of them is non-zero.
#   1965
#   1966                                               10. ``Y = cdist(XA, XB, 'chebyshev')``
#   1967
#   1968                                                  Computes the Chebyshev distance between the points. The
#   1969                                                  Chebyshev distance between two n-vectors ``u`` and ``v`` is the
#   1970                                                  maximum norm-1 distance between their respective elements. More
#   1971                                                  precisely, the distance is given by
#   1972
#   1973                                                  .. math::
#   1974
#   1975                                                     d(u,v) = \\max_i {|u_i-v_i|}.
#   1976
#   1977                                               11. ``Y = cdist(XA, XB, 'canberra')``
#   1978
#   1979                                                  Computes the Canberra distance between the points. The
#   1980                                                  Canberra distance between two points ``u`` and ``v`` is
#   1981
#   1982                                                  .. math::
#   1983
#   1984                                                    d(u,v) = \\sum_i \\frac{|u_i-v_i|}
#   1985                                                                         {|u_i|+|v_i|}.
#   1986
#   1987                                               12. ``Y = cdist(XA, XB, 'braycurtis')``
#   1988
#   1989                                                  Computes the Bray-Curtis distance between the points. The
#   1990                                                  Bray-Curtis distance between two points ``u`` and ``v`` is
#   1991
#   1992
#   1993                                                  .. math::
#   1994
#   1995                                                       d(u,v) = \\frac{\\sum_i (|u_i-v_i|)}
#   1996                                                                     {\\sum_i (|u_i+v_i|)}
#   1997
#   1998                                               13. ``Y = cdist(XA, XB, 'mahalanobis', VI=None)``
#   1999
#   2000                                                  Computes the Mahalanobis distance between the points. The
#   2001                                                  Mahalanobis distance between two points ``u`` and ``v`` is
#   2002                                                  :math:`\\sqrt{(u-v)(1/V)(u-v)^T}` where :math:`(1/V)` (the ``VI``
#   2003                                                  variable) is the inverse covariance. If ``VI`` is not None,
#   2004                                                  ``VI`` will be used as the inverse covariance matrix.
#   2005
#   2006                                               14. ``Y = cdist(XA, XB, 'yule')``
#   2007
#   2008                                                  Computes the Yule distance between the boolean
#   2009                                                  vectors. (see `yule` function documentation)
#   2010
#   2011                                               15. ``Y = cdist(XA, XB, 'matching')``
#   2012
#   2013                                                  Synonym for 'hamming'.
#   2014
#   2015                                               16. ``Y = cdist(XA, XB, 'dice')``
#   2016
#   2017                                                  Computes the Dice distance between the boolean vectors. (see
#   2018                                                  `dice` function documentation)
#   2019
#   2020                                               17. ``Y = cdist(XA, XB, 'kulsinski')``
#   2021
#   2022                                                  Computes the Kulsinski distance between the boolean
#   2023                                                  vectors. (see `kulsinski` function documentation)
#   2024
#   2025                                               18. ``Y = cdist(XA, XB, 'rogerstanimoto')``
#   2026
#   2027                                                  Computes the Rogers-Tanimoto distance between the boolean
#   2028                                                  vectors. (see `rogerstanimoto` function documentation)
#   2029
#   2030                                               19. ``Y = cdist(XA, XB, 'russellrao')``
#   2031
#   2032                                                  Computes the Russell-Rao distance between the boolean
#   2033                                                  vectors. (see `russellrao` function documentation)
#   2034
#   2035                                               20. ``Y = cdist(XA, XB, 'sokalmichener')``
#   2036
#   2037                                                  Computes the Sokal-Michener distance between the boolean
#   2038                                                  vectors. (see `sokalmichener` function documentation)
#   2039
#   2040                                               21. ``Y = cdist(XA, XB, 'sokalsneath')``
#   2041
#   2042                                                  Computes the Sokal-Sneath distance between the vectors. (see
#   2043                                                  `sokalsneath` function documentation)
#   2044
#   2045
#   2046                                               22. ``Y = cdist(XA, XB, 'wminkowski')``
#   2047
#   2048                                                  Computes the weighted Minkowski distance between the
#   2049                                                  vectors. (see `wminkowski` function documentation)
#   2050
#   2051                                               23. ``Y = cdist(XA, XB, f)``
#   2052
#   2053                                                  Computes the distance between all pairs of vectors in X
#   2054                                                  using the user supplied 2-arity function f. For example,
#   2055                                                  Euclidean distance between the vectors could be computed
#   2056                                                  as follows::
#   2057
#   2058                                                    dm = cdist(XA, XB, lambda u, v: np.sqrt(((u-v)**2).sum()))
#   2059
#   2060                                                  Note that you should avoid passing a reference to one of
#   2061                                                  the distance functions defined in this library. For example,::
#   2062
#   2063                                                    dm = cdist(XA, XB, sokalsneath)
#   2064
#   2065                                                  would calculate the pair-wise distances between the vectors in
#   2066                                                  X using the Python function `sokalsneath`. This would result in
#   2067                                                  sokalsneath being called :math:`{n \\choose 2}` times, which
#   2068                                                  is inefficient. Instead, the optimized C version is more
#   2069                                                  efficient, and we call it using the following syntax::
#   2070
#   2071                                                    dm = cdist(XA, XB, 'sokalsneath')
#   2072
#   2073                                               Examples
#   2074                                               --------
#   2075                                               Find the Euclidean distances between four 2-D coordinates:
#   2076
#   2077                                               >>> from scipy.spatial import distance
#   2078                                               >>> coords = [(35.0456, -85.2672),
#   2079                                               ...           (35.1174, -89.9711),
#   2080                                               ...           (35.9728, -83.9422),
#   2081                                               ...           (36.1667, -86.7833)]
#   2082                                               >>> distance.cdist(coords, coords, 'euclidean')
#   2083                                               array([[ 0.    ,  4.7044,  1.6172,  1.8856],
#   2084                                                      [ 4.7044,  0.    ,  6.0893,  3.3561],
#   2085                                                      [ 1.6172,  6.0893,  0.    ,  2.8477],
#   2086                                                      [ 1.8856,  3.3561,  2.8477,  0.    ]])
#   2087
#   2088
#   2089                                               Find the Manhattan distance from a 3-D point to the corners of the unit
#   2090                                               cube:
#   2091
#   2092                                               >>> a = np.array([[0, 0, 0],
#   2093                                               ...               [0, 0, 1],
#   2094                                               ...               [0, 1, 0],
#   2095                                               ...               [0, 1, 1],
#   2096                                               ...               [1, 0, 0],
#   2097                                               ...               [1, 0, 1],
#   2098                                               ...               [1, 1, 0],
#   2099                                               ...               [1, 1, 1]])
#   2100                                               >>> b = np.array([[ 0.1,  0.2,  0.4]])
#   2101                                               >>> distance.cdist(a, b, 'cityblock')
#   2102                                               array([[ 0.7],
#   2103                                                      [ 0.9],
#   2104                                                      [ 1.3],
#   2105                                                      [ 1.5],
#   2106                                                      [ 1.5],
#   2107                                                      [ 1.7],
#   2108                                                      [ 2.1],
#   2109                                                      [ 2.3]])
#   2110
#   2111                                               """
#   2112                                               # You can also call this as:
#   2113                                               #     Y = cdist(XA, XB, 'test_abc')
#   2114                                               # where 'abc' is the metric being tested.  This computes the distance
#   2115                                               # between all pairs of vectors in XA and XB using the distance metric 'abc'
#   2116                                               # but with a more succinct, verifiable, but less efficient implementation.
#   2117
#   2118                                               # Store input arguments to check whether we can modify later.
#   2119         1          4.0      4.0      0.0      input_XA, input_XB = XA, XB
#   2120
#   2121         1         14.0     14.0      0.1      XA = np.asarray(XA, order='c')
#   2122         1          5.0      5.0      0.0      XB = np.asarray(XB, order='c')
#   2123
#   2124                                               # The C code doesn't do striding.
#   2125         1          6.0      6.0      0.0      XA = _copy_array_if_base_present(XA)
#   2126         1          4.0      4.0      0.0      XB = _copy_array_if_base_present(XB)
#   2127
#   2128         1          4.0      4.0      0.0      s = XA.shape
#   2129         1          3.0      3.0      0.0      sB = XB.shape
#   2130
#   2131         1          4.0      4.0      0.0      if len(s) != 2:
#   2132                                                   raise ValueError('XA must be a 2-dimensional array.')
#   2133         1          3.0      3.0      0.0      if len(sB) != 2:
#   2134                                                   raise ValueError('XB must be a 2-dimensional array.')
#   2135         1          4.0      4.0      0.0      if s[1] != sB[1]:
#   2136                                                   raise ValueError('XA and XB must have the same number of columns '
#   2137                                                                    '(i.e. feature dimension.)')
#   2138
#   2139         1          3.0      3.0      0.0      mA = s[0]
#   2140         1          3.0      3.0      0.0      mB = sB[0]
#   2141         1          3.0      3.0      0.0      n = s[1]
#   2142         1        286.0    286.0      2.0      dm = np.zeros((mA, mB), dtype=np.double)
#   2143
#   2144                                               # validate input for multi-args metrics
#   2145         1          3.0      3.0      0.0      if(metric in ['minkowski', 'mi', 'm', 'pnorm', 'test_minkowski'] or
#   2146         1          2.0      2.0      0.0         metric == minkowski):
#   2147                                                   p = _validate_minkowski_args(p)
#   2148                                                   _filter_deprecated_kwargs(w=w, V=V, VI=VI)
#   2149         1          2.0      2.0      0.0      elif(metric in ['wminkowski', 'wmi', 'wm', 'wpnorm', 'test_wminkowski'] or
#   2150         1          2.0      2.0      0.0           metric == wminkowski):
#   2151                                                   p, w = _validate_wminkowski_args(p, w)
#   2152                                                   _filter_deprecated_kwargs(V=V, VI=VI)
#   2153         1          2.0      2.0      0.0      elif(metric in ['seuclidean', 'se', 's', 'test_seuclidean'] or
#   2154         1          2.0      2.0      0.0           metric == seuclidean):
#   2155                                                   V = _validate_seuclidean_args(np.vstack([XA, XB]), n, V)
#   2156                                                   _filter_deprecated_kwargs(p=p, w=w, VI=VI)
#   2157         1          2.0      2.0      0.0      elif(metric in ['mahalanobis', 'mahal', 'mah', 'test_mahalanobis'] or
#   2158         1          2.0      2.0      0.0           metric == mahalanobis):
#   2159                                                   VI = _validate_mahalanobis_args(np.vstack([XA, XB]), mA + mB, n, VI)
#   2160                                                   _filter_deprecated_kwargs(p=p, w=w, V=V)
#   2161                                               else:
#   2162         1          8.0      8.0      0.1          _filter_deprecated_kwargs(p=p, w=w, V=V, VI=VI)
#   2163
#   2164         1         12.0     12.0      0.1      if callable(metric):
#   2165                                                   # metrics that expects only doubles:
#   2166                                                   if metric in [braycurtis, canberra, chebyshev, cityblock, correlation,
#   2167                                                                 cosine, euclidean, mahalanobis, minkowski, sqeuclidean,
#   2168                                                                 seuclidean, wminkowski]:
#   2169                                                       XA = _convert_to_double(XA)
#   2170                                                       XB = _convert_to_double(XB)
#   2171                                                   # metrics that expects only bools:
#   2172                                                   elif metric in [dice, kulsinski, rogerstanimoto, russellrao,
#   2173                                                                   sokalmichener, sokalsneath, yule]:
#   2174                                                       XA = _convert_to_bool(XA)
#   2175                                                       XB = _convert_to_bool(XB)
#   2176                                                   # metrics that may receive multiple types:
#   2177                                                   elif metric in [matching, hamming, jaccard]:
#   2178                                                       if XA.dtype == bool:
#   2179                                                           XA = _convert_to_bool(XA)
#   2180                                                           XB = _convert_to_bool(XB)
#   2181                                                       else:
#   2182                                                           XA = _convert_to_double(XA)
#   2183                                                           XB = _convert_to_double(XB)
#   2184
#   2185                                                   # metrics that expects multiple args
#   2186                                                   if metric == minkowski:
#   2187                                                       metric = partial(minkowski, p=p)
#   2188                                                   elif metric == wminkowski:
#   2189                                                       metric = partial(wminkowski, p=p, w=w)
#   2190                                                   elif metric == seuclidean:
#   2191                                                       metric = partial(seuclidean, V=V)
#   2192                                                   elif metric == mahalanobis:
#   2193                                                       metric = partial(mahalanobis, VI=VI)
#   2194
#   2195                                                   for i in xrange(0, mA):
#   2196                                                       for j in xrange(0, mB):
#   2197                                                           dm[i, j] = metric(XA[i, :], XB[j, :])
#   2198
#   2199         1          3.0      3.0      0.0      elif isinstance(metric, string_types):
#   2200         1          4.0      4.0      0.0          mstr = metric.lower()
#   2201
#   2202         1          3.0      3.0      0.0          try:
#   2203         1          3.0      3.0      0.0              validate, cdist_fn = _SIMPLE_CDIST[mstr]
#   2204         1         16.0     16.0      0.1              XA = validate(XA)
#   2205         1          7.0      7.0      0.0              XB = validate(XB)
#   2206         1      14034.0  14034.0     97.1              cdist_fn(XA, XB, dm)
#   2207         1          3.0      3.0      0.0              return dm
#   2208                                                   except KeyError:
#   2209                                                       pass
#   2210
#   2211                                                   if mstr in ['matching', 'hamming', 'hamm', 'ha', 'h']:
#   2212                                                       if XA.dtype == bool:
#   2213                                                           XA = _convert_to_bool(XA)
#   2214                                                           XB = _convert_to_bool(XB)
#   2215                                                           _distance_wrap.cdist_hamming_bool_wrap(XA, XB, dm)
#   2216                                                       else:
#   2217                                                           XA = _convert_to_double(XA)
#   2218                                                           XB = _convert_to_double(XB)
#   2219                                                           _distance_wrap.cdist_hamming_wrap(XA, XB, dm)
#   2220                                                   elif mstr in ['jaccard', 'jacc', 'ja', 'j']:
#   2221                                                       if XA.dtype == bool:
#   2222                                                           XA = _convert_to_bool(XA)
#   2223                                                           XB = _convert_to_bool(XB)
#   2224                                                           _distance_wrap.cdist_jaccard_bool_wrap(XA, XB, dm)
#   2225                                                       else:
#   2226                                                           XA = _convert_to_double(XA)
#   2227                                                           XB = _convert_to_double(XB)
#   2228                                                           _distance_wrap.cdist_jaccard_wrap(XA, XB, dm)
#   2229                                                   elif mstr in ['minkowski', 'mi', 'm', 'pnorm']:
#   2230                                                       XA = _convert_to_double(XA)
#   2231                                                       XB = _convert_to_double(XB)
#   2232                                                       _distance_wrap.cdist_minkowski_wrap(XA, XB, dm, p=p)
#   2233                                                   elif mstr in ['wminkowski', 'wmi', 'wm', 'wpnorm']:
#   2234                                                       XA = _convert_to_double(XA)
#   2235                                                       XB = _convert_to_double(XB)
#   2236                                                       _distance_wrap.cdist_weighted_minkowski_wrap(XA, XB, dm, p=p, w=w)
#   2237                                                   elif mstr in ['seuclidean', 'se', 's']:
#   2238                                                       XA = _convert_to_double(XA)
#   2239                                                       XB = _convert_to_double(XB)
#   2240                                                       _distance_wrap.cdist_seuclidean_wrap(XA, XB, dm, V=V)
#   2241                                                   elif mstr in ['cosine', 'cos']:
#   2242                                                       XA = _convert_to_double(XA)
#   2243                                                       XB = _convert_to_double(XB)
#   2244                                                       _cosine_cdist(XA, XB, dm)
#   2245                                                   elif mstr in ['correlation', 'co']:
#   2246                                                       XA = _convert_to_double(XA)
#   2247                                                       XB = _convert_to_double(XB)
#   2248                                                       XA = XA.copy() if XA is input_XA else XA
#   2249                                                       XB = XB.copy() if XB is input_XB else XB
#   2250                                                       XA -= XA.mean(axis=1)[:, np.newaxis]
#   2251                                                       XB -= XB.mean(axis=1)[:, np.newaxis]
#   2252                                                       _cosine_cdist(XA, XB, dm)
#   2253                                                   elif mstr in ['mahalanobis', 'mahal', 'mah']:
#   2254                                                       XA = _convert_to_double(XA)
#   2255                                                       XB = _convert_to_double(XB)
#   2256                                                       # sqrt((u-v)V^(-1)(u-v)^T)
#   2257                                                       _distance_wrap.cdist_mahalanobis_wrap(XA, XB, dm, VI=VI)
#   2258                                                   elif mstr.startswith("test_"):
#   2259                                                       if mstr in _TEST_METRICS:
#   2260                                                           kwargs = {"p":p, "w":w, "V":V, "VI":VI}
#   2261                                                           dm = cdist(XA, XB, _TEST_METRICS[mstr], **kwargs)
#   2262                                                       else:
#   2263                                                           raise ValueError('Unknown "Test" Distance Metric: %s' % mstr[5:])
#   2264                                                   else:
#   2265                                                       raise ValueError('Unknown Distance Metric: %s' % mstr)
#   2266                                               else:
#   2267                                                   raise TypeError('2nd argument metric must be a string identifier '
#   2268                                                                   'or a function.')
#   2269                                               return dm

# %% [markdown]
# ### Another one

# %%
from sklearn.metrics.pairwise import euclidean_distances as sklearn_euclidean_distances

# %%
D_sklearn = sklearn_euclidean_distances(X, Y)
np.abs(D_sklearn - D_naive).sum()
# Out:
# 2.0565096292557428e-09

# %%
# %%timeit 
sklearn_euclidean_distances(X, Y)
# Out:
# 2.25 ms ± 26.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
profile_print(sklearn_euclidean_distances, X, Y)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.003574 s
# File: /home/dmitry/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py
# Function: euclidean_distances at line 163
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    163                                           def euclidean_distances(X, Y=None, Y_norm_squared=None, squared=False,
#    164                                                                   X_norm_squared=None):
#    165                                               """
#    166                                               Considering the rows of X (and Y=X) as vectors, compute the
#    167                                               distance matrix between each pair of vectors.
#    168
#    169                                               For efficiency reasons, the euclidean distance between a pair of row
#    170                                               vector x and y is computed as::
#    171
#    172                                                   dist(x, y) = sqrt(dot(x, x) - 2 * dot(x, y) + dot(y, y))
#    173
#    174                                               This formulation has two advantages over other ways of computing distances.
#    175                                               First, it is computationally efficient when dealing with sparse data.
#    176                                               Second, if one argument varies but the other remains unchanged, then
#    177                                               `dot(x, x)` and/or `dot(y, y)` can be pre-computed.
#    178
#    179                                               However, this is not the most precise way of doing this computation, and
#    180                                               the distance matrix returned by this function may not be exactly
#    181                                               symmetric as required by, e.g., ``scipy.spatial.distance`` functions.
#    182
#    183                                               Read more in the :ref:`User Guide <metrics>`.
#    184
#    185                                               Parameters
#    186                                               ----------
#    187                                               X : {array-like, sparse matrix}, shape (n_samples_1, n_features)
#    188
#    189                                               Y : {array-like, sparse matrix}, shape (n_samples_2, n_features)
#    190
#    191                                               Y_norm_squared : array-like, shape (n_samples_2, ), optional
#    192                                                   Pre-computed dot-products of vectors in Y (e.g.,
#    193                                                   ``(Y**2).sum(axis=1)``)
#    194
#    195                                               squared : boolean, optional
#    196                                                   Return squared Euclidean distances.
#    197
#    198                                               X_norm_squared : array-like, shape = [n_samples_1], optional
#    199                                                   Pre-computed dot-products of vectors in X (e.g.,
#    200                                                   ``(X**2).sum(axis=1)``)
#    201
#    202                                               Returns
#    203                                               -------
#    204                                               distances : {array, sparse matrix}, shape (n_samples_1, n_samples_2)
#    205
#    206                                               Examples
#    207                                               --------
#    208                                               >>> from sklearn.metrics.pairwise import euclidean_distances
#    209                                               >>> X = [[0, 1], [1, 1]]
#    210                                               >>> # distance between rows of X
#    211                                               >>> euclidean_distances(X, X)
#    212                                               array([[ 0.,  1.],
#    213                                                      [ 1.,  0.]])
#    214                                               >>> # get distance to origin
#    215                                               >>> euclidean_distances(X, [[0, 0]])
#    216                                               array([[ 1.        ],
#    217                                                      [ 1.41421356]])
#    218
#    219                                               See also
#    220                                               --------
#    221                                               paired_distances : distances betweens pairs of elements of X and Y.
#    222                                               """
#    223         1        335.0    335.0      9.4      X, Y = check_pairwise_arrays(X, Y)
#    224
#    225         1          1.0      1.0      0.0      if X_norm_squared is not None:
#    226                                                   XX = check_array(X_norm_squared)
#    227                                                   if XX.shape == (1, X.shape[0]):
#    228                                                       XX = XX.T
#    229                                                   elif XX.shape != (X.shape[0], 1):
#    230                                                       raise ValueError(
#    231                                                           "Incompatible dimensions for X and X_norm_squared")
#    232                                               else:
#    233         1         77.0     77.0      2.2          XX = row_norms(X, squared=True)[:, np.newaxis]
#    234
#    235         1          1.0      1.0      0.0      if X is Y:  # shortcut in the common case euclidean_distances(X, X)
#    236                                                   YY = XX.T
#    237         1          1.0      1.0      0.0      elif Y_norm_squared is not None:
#    238                                                   YY = np.atleast_2d(Y_norm_squared)
#    239
#    240                                                   if YY.shape != (1, Y.shape[0]):
#    241                                                       raise ValueError(
#    242                                                           "Incompatible dimensions for Y and Y_norm_squared")
#    243                                               else:
#    244         1         37.0     37.0      1.0          YY = row_norms(Y, squared=True)[np.newaxis, :]
#    245
#    246         1       1070.0   1070.0     29.9      distances = safe_sparse_dot(X, Y.T, dense_output=True)
#    247         1        234.0    234.0      6.5      distances *= -2
#    248         1        403.0    403.0     11.3      distances += XX
#    249         1        301.0    301.0      8.4      distances += YY
#    250         1        444.0    444.0     12.4      np.maximum(distances, 0, out=distances)
#    251
#    252         1          1.0      1.0      0.0      if X is Y:
#    253                                                   # Ensure that distances between vectors and themselves are set to 0.0.
#    254                                                   # This may not be the case due to floating point rounding errors.
#    255                                                   distances.flat[::distances.shape[0] + 1] = 0.0
#    256
#    257         1        669.0    669.0     18.7      return distances if squared else np.sqrt(distances, out=distances)

# %% [markdown]
# ### Numba

# %%
from numba import jit

# %%
@jit(nopython=True)
def vector_distance(x, y):
    dist = ((x - y) ** 2).sum()
    return np.sqrt(dist)

@jit(nopython=True)
def numba_mdist(X, Y):
    D = np.zeros((X.shape[0], Y.shape[0]))
    for i in range(X.shape[0]):
        for j in range(Y.shape[0]):
            D[i, j] = vector_distance(X[i, :], Y[j, :])
    return D

# %%
D_numba = numba_mdist(X, Y)
np.abs(D_numba - D_naive).sum()
# Out:
# 3.3542448818479897e-09

# %%
# %%timeit 
numba_mdist(X, Y) # x20
# Out:
# 86.6 ms ± 726 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# useless
profile_print(numba_mdist, X, Y)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0 s
# File: <ipython-input-38-e9c99ed9c1b7>
# Function: numba_mdist at line 6
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      6                                           @jit(nopython=True)
#      7                                           def numba_mdist(X, Y):
#      8                                               D = np.zeros((X.shape[0], Y.shape[0]))
#      9                                               for i in range(X.shape[0]):
#     10                                                   for j in range(Y.shape[0]):
#     11                                                       D[i, j] = vector_distance(X[i, :], Y[j, :])
#     12                                               return D

# %% [markdown]
# ### Broadcast Numba

# %%
@jit(nopython=True)
def broadcast_numba_dist(X, Y):
    D = np.zeros((X.shape[0], Y.shape[0]))
    for j in range(Y.shape[0]):
        dist = ((X - Y[j, :]) ** 2).sum(axis=1)
        D[:, j] = np.sqrt(dist)
    return D

# %%
D_br_numba = broadcast_numba_dist(X, Y)
np.abs(D_br_numba - D_naive).sum()
# Out:
# 3.3859635095723206e-09

# %%
# %%timeit 
broadcast_numba_dist(X, Y)
# Out:
# 53.7 ms ± 216 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Numpy numba

# %%
@jit(nopython=True)
def numpy_numba_dist(X, Y):
    x_dist = (X ** 2).sum(axis=1)
    y_dist = (Y ** 2).sum(axis=1)
#     xy_dist = X.dot(Y.T)
#   !!!!!!!!!!!!!!!!!!!!!!!!!!!
    xy_dist = np.dot(X, Y.T)
    dist = - 2 * xy_dist + y_dist + x_dist.reshape(-1, 1)
    return np.sqrt(dist)

# %%
D_np_numba = numpy_numba_dist(X, Y)
np.abs(D_np_numba - D_naive).sum()
# Out:
# 2.8838442744927306e-09

# %%
# %%timeit 
numpy_numba_dist(X, Y)
# Out:
# 3.7 ms ± 12.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Cython

# %%
# %%cython
# import numpy as np
# cimport numpy as np
#
# def vector_distance(x, y):
#     dist = ((x - y) ** 2).sum()
#     return np.sqrt(dist)
#
#
# def cython_mdist(X, Y):
#     D = np.zeros((X.shape[0], Y.shape[0]))
#     for i in range(X.shape[0]):
#         for j in range(Y.shape[0]):
#             D[i, j] = vector_distance(X[i, :], Y[j, :])
#     return D

# %%
D_cython = cython_mdist(X, Y)
np.abs(D_cython - D_naive).sum()
# Out:
# 0.0

# %%
# %%timeit 
cython_mdist(X, Y)
# Out:
# 1.5 s ± 21.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# useless
profile_print(cython_mdist, X, Y)
# Out:
# /home/dmitry/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Could not extract a code object for the object <built-in function cython_mdist>
#   This is separate from the ipykernel package so we can avoid doing imports until
# Timer unit: 1e-06 s

# %% [markdown]
# ### Cython annotations

# %%
# %%cython -a
# import numpy as np
# cimport numpy as np
#
# cdef vector_distance(x, y):
#     dist = ((x - y) ** 2).sum()
#     return np.sqrt(dist)
#
#
# cdef cython_mdist(X, Y):
#     D = np.zeros((X.shape[0], Y.shape[0]))
#     for i in range(X.shape[0]):
#         for j in range(Y.shape[0]):
#             D[i, j] = vector_distance(X[i, :], Y[j, :])
#     return D
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_3b35666fe40d212e898e15ad4d0db77b.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
# %%cython -a
# import numpy as np
# cimport numpy as np
#
# cdef vector_distance(x, y):
#     dist = ((x - y) ** 2).sum()
#     return np.sqrt(dist)
#
#
# cdef cython_mdist(np.ndarray[np.float64_t, ndim=2] X,
#                   np.ndarray[np.float64_t, ndim=2] Y):
#     cdef np.ndarray[np.float64_t, ndim=2] D;
#     D = np.zeros((X.shape[0], Y.shape[0]))
#     for i in range(X.shape[0]):
#         for j in range(Y.shape[0]):
#             D[i, j] = vector_distance(X[i, :], Y[j, :])
#     return D
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_b31d4426f7d56463d0fa3e527437f0ac.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
D_cython = cython_mdist(X, Y)
np.abs(D_cython - D_naive).sum()
# Out:
# 0.0

# %%
# %%timeit 
cython_mdist(X, Y)
# Out:
# 1.56 s ± 33.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%cython -a
# import numpy as np
# cimport numpy as np
# cimport cython
#
# from libc.math cimport sqrt
#
#
# cpdef cython_mdist(np.ndarray[np.float64_t, ndim=2] X,
#                   np.ndarray[np.float64_t, ndim=2] Y):
#     cdef np.ndarray[np.float64_t, ndim=2] D;
#     D = np.zeros((X.shape[0], Y.shape[0]), dtype=np.float64)
#     cdef np.float64_t dist = 0.0;
#     for i in range(X.shape[0]):
#         for j in range(Y.shape[0]):
#             dist = 0.0
#             for d in range(X.shape[1]):
#                 dist += (X[i, d] - Y[j, d]) ** 2
#             D[i, j] = sqrt(dist)
#     return D
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_fbce6e26efe55ce75a5f5a68dcbe4c8c.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
D_cython = cython_mdist(X, Y)
np.abs(D_cython - D_naive).sum()
# Out:
# 3.3542448818479897e-09

# %%
# %%timeit 
cython_mdist(X, Y)
# Out:
# 45.1 ms ± 653 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%cython -a
# import numpy as np
# cimport numpy as np
# cimport cython
#
# from libc.math cimport sqrt
#
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# cpdef cython_mdist(np.ndarray[np.float64_t, ndim=2] X,
#                   np.ndarray[np.float64_t, ndim=2] Y):
#     cdef np.ndarray[np.float64_t, ndim=2] D;
#     D = np.zeros((X.shape[0], Y.shape[0]), dtype=np.float64)
#     cdef np.float64_t dist = 0.0;
#     for i in range(X.shape[0]):
#         for j in range(Y.shape[0]):
#             dist = 0.0
#             for d in range(X.shape[1]):
#                 dist += (X[i, d] - Y[j, d]) ** 2
#             D[i, j] = sqrt(dist)
#     return D
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.25.2 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_d682ab9f1477daa2f537314f095232a1.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-color

# %%
D_cython = cython_mdist(X, Y)
np.abs(D_cython - D_naive).sum()
# Out:
# 3.3859635095723206e-09

# %%
# %%timeit 
cython_mdist(X, Y)
# Out:
# 27.6 ms ± 446 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
